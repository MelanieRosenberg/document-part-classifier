# %%
import os
import re
from typing import List, Dict, Tuple
import logging
import json

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Define the tags we want to keep
TARGET_TAGS = {'TEXT', 'FORM', 'TABLE'}

def convert_document(input_file: str, output_dir: str) -> Dict:
    """
    Extract content from TEXT, FORM, and TABLE tags from a single document.
    Create two output files for each input document:
    1. [filename]_lines.txt - containing just the content lines
    2. [filename]_labels.txt - containing the labels for each line
    
    Args:
        input_file (str): Path to the input XML-tagged document
        output_dir (str): Directory to save the output files
        
    Returns:
        Dict: Statistics about the conversion process
    """
    stats = {
        'filename': os.path.basename(input_file),
        'lines_extracted': 0,
        'tags_kept': {'TEXT': 0, 'FORM': 0, 'TABLE': 0},
        'char_counts': {'TEXT': 0, 'FORM': 0, 'TABLE': 0},
        'tags_skipped': {}
    }
    
    try:
        # Read the input file
        with open(input_file, 'r', encoding='utf-8') as f:
            content = f.read()
        
        # Extract lines and labels
        document_lines = []
        document_labels = []
        
        # Match target tags and their content
        pattern = r'<([A-Za-z][^>]*)>(.*?)</\1>'
        matches = re.finditer(pattern, content, re.DOTALL)
        
        for match in matches:
            tag = match.group(1)  # The tag name (e.g., TEXT, FORM, TABLE)
            text = match.group(2)  # The content between tags
            
            # Only process content from target tags
            if tag in TARGET_TAGS:
                # Split text into lines and keep non-empty ones
                lines = [line.strip() for line in text.split('\n') if line.strip()]
                
                # Add each line and its corresponding label
                for line in lines:
                    document_lines.append(line)
                    document_labels.append(tag)
                    stats['tags_kept'][tag] += 1
                    stats['char_counts'][tag] += len(line)
            else:
                # Count skipped tags
                if tag not in stats['tags_skipped']:
                    stats['tags_skipped'][tag] = 0
                stats['tags_skipped'][tag] += 1
        
        stats['lines_extracted'] = len(document_lines)
        
        # Create the output filenames based on the input filename
        base_filename = os.path.basename(input_file)
        name_without_ext = os.path.splitext(base_filename)[0]
        
        lines_file = os.path.join(output_dir, f"{name_without_ext}_lines.txt")
        labels_file = os.path.join(output_dir, f"{name_without_ext}_labels.txt")
        
        # Write the lines and labels to separate files
        if document_lines:
            with open(lines_file, 'w', encoding='utf-8') as f:
                for line in document_lines:
                    f.write(f"{line}\n")
            
            with open(labels_file, 'w', encoding='utf-8') as f:
                for label in document_labels:
                    f.write(f"{label}\n")
            
            logger.info(f"Created {lines_file} with {len(document_lines)} lines")
        else:
            logger.warning(f"No matching content found in {input_file}")
        
    except Exception as e:
        logger.error(f"Error processing {input_file}: {str(e)}")
    
    return stats

def process_directory(input_dir: str, output_dir: str) -> Dict:
    """
    Process all files in a directory, creating two output files per input document.
    Also generates detailed statistics about line counts per document and overall.
    
    Args:
        input_dir (str): Directory containing input files
        output_dir (str): Directory to save output files
        
    Returns:
        Dict: Summary statistics
    """
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    summary = {
        'files_processed': 0,
        'files_with_content': 0,
        'total_lines_extracted': 0,
        'tag_counts': {'TEXT': 0, 'FORM': 0, 'TABLE': 0},
        'char_counts': {'TEXT': 0, 'FORM': 0, 'TABLE': 0},
        'skipped_tags': {},
        'per_document_stats': []
    }
    
    # Process each file in the input directory
    for filename in os.listdir(input_dir):
        input_path = os.path.join(input_dir, filename)
        
        # Skip directories
        if os.path.isdir(input_path):
            continue
        
        # Process the file
        stats = convert_document(input_path, output_dir)
        
        # Save detailed stats for this document
        doc_stats = {
            'filename': stats['filename'],
            'total_lines': stats['lines_extracted'],
            'TEXT_lines': stats['tags_kept']['TEXT'],
            'FORM_lines': stats['tags_kept']['FORM'],
            'TABLE_lines': stats['tags_kept']['TABLE'],
            'TEXT_chars': stats['char_counts']['TEXT'],
            'FORM_chars': stats['char_counts']['FORM'],
            'TABLE_chars': stats['char_counts']['TABLE'],
            'TEXT_avg_len': stats['char_counts']['TEXT'] / stats['tags_kept']['TEXT'] if stats['tags_kept']['TEXT'] > 0 else 0,
            'FORM_avg_len': stats['char_counts']['FORM'] / stats['tags_kept']['FORM'] if stats['tags_kept']['FORM'] > 0 else 0,
            'TABLE_avg_len': stats['char_counts']['TABLE'] / stats['tags_kept']['TABLE'] if stats['tags_kept']['TABLE'] > 0 else 0
        }
        summary['per_document_stats'].append(doc_stats)
        
        # Update summary statistics
        summary['files_processed'] += 1
        if stats['lines_extracted'] > 0:
            summary['files_with_content'] += 1
        
        summary['total_lines_extracted'] += stats['lines_extracted']
        
        for tag in TARGET_TAGS:
            summary['tag_counts'][tag] += stats['tags_kept'][tag]
            summary['char_counts'][tag] += stats['char_counts'][tag]
        
        for tag, count in stats['tags_skipped'].items():
            if tag not in summary['skipped_tags']:
                summary['skipped_tags'][tag] = 0
            summary['skipped_tags'][tag] += count
    
    # Sort per-document stats by filename for easier reading
    summary['per_document_stats'].sort(key=lambda x: x['filename'])
    
    # Print summary
    logger.info(f"\nProcessing complete. Summary stats:")
    logger.info(f"Files processed: {summary['files_processed']}")
    logger.info(f"Files with content: {summary['files_with_content']}")
    logger.info(f"Total lines extracted: {summary['total_lines_extracted']}")
    logger.info("Lines per tag type:")
    for tag in TARGET_TAGS:
        total_lines = summary['tag_counts'].get(tag, 0)
        total_chars = summary['char_counts'].get(tag, 0)
        avg_len = total_chars / total_lines if total_lines > 0 else 0
        logger.info(f"  {tag}: {total_lines} lines, {total_chars} characters, {avg_len:.2f} avg chars/line")
    
    # Save per-document statistics to a JSON file
    stats_file = os.path.join(output_dir, "document_statistics.json")
    with open(stats_file, 'w', encoding='utf-8') as f:
        json.dump(summary, f, indent=2)
    logger.info(f"Detailed statistics saved to {stats_file}")
    
    # Also save a CSV for easy spreadsheet import
    csv_file = os.path.join(output_dir, "document_statistics.csv")
    with open(csv_file, 'w', encoding='utf-8') as f:
        # Write header
        f.write("Filename,Total Lines,TEXT Lines,FORM Lines,TABLE Lines,TEXT Chars,FORM Chars,TABLE Chars,TEXT Avg Len,FORM Avg Len,TABLE Avg Len\n")
        
        # Write per-document stats
        for doc in summary['per_document_stats']:
            f.write(f"{doc['filename']},{doc['total_lines']},{doc['TEXT_lines']},{doc['FORM_lines']},{doc['TABLE_lines']},{doc['TEXT_chars']},{doc['FORM_chars']},{doc['TABLE_chars']},{doc['TEXT_avg_len']:.2f},{doc['FORM_avg_len']:.2f},{doc['TABLE_avg_len']:.2f}\n")
        
        # Calculate overall averages
        text_avg = summary['char_counts']['TEXT'] / summary['tag_counts']['TEXT'] if summary['tag_counts']['TEXT'] > 0 else 0
        form_avg = summary['char_counts']['FORM'] / summary['tag_counts']['FORM'] if summary['tag_counts']['FORM'] > 0 else 0
        table_avg = summary['char_counts']['TABLE'] / summary['tag_counts']['TABLE'] if summary['tag_counts']['TABLE'] > 0 else 0
        
        # Write summary row
        f.write(f"TOTAL,{summary['total_lines_extracted']},{summary['tag_counts']['TEXT']},{summary['tag_counts']['FORM']},{summary['tag_counts']['TABLE']},{summary['char_counts']['TEXT']},{summary['char_counts']['FORM']},{summary['char_counts']['TABLE']},{text_avg:.2f},{form_avg:.2f},{table_avg:.2f}\n")
    
    logger.info(f"CSV statistics saved to {csv_file}")
    
    # Print detailed statistics for each document
    logger.info("\nPer-document statistics:")
    logger.info(f"{'Filename':<30} {'Total':<8} {'TEXT':<8} {'FORM':<8} {'TABLE':<8} {'TEXT Avg':<10} {'FORM Avg':<10} {'TABLE Avg':<10}")
    logger.info("-" * 100)
    
    for doc in summary['per_document_stats']:
        logger.info(f"{doc['filename']:<30} {doc['total_lines']:<8} {doc['TEXT_lines']:<8} {doc['FORM_lines']:<8} {doc['TABLE_lines']:<8} {doc['TEXT_avg_len']:<10.2f} {doc['FORM_avg_len']:<10.2f} {doc['TABLE_avg_len']:<10.2f}")
    
    # Calculate overall averages
    text_avg = summary['char_counts']['TEXT'] / summary['tag_counts']['TEXT'] if summary['tag_counts']['TEXT'] > 0 else 0
    form_avg = summary['char_counts']['FORM'] / summary['tag_counts']['FORM'] if summary['tag_counts']['FORM'] > 0 else 0
    table_avg = summary['char_counts']['TABLE'] / summary['tag_counts']['TABLE'] if summary['tag_counts']['TABLE'] > 0 else 0
    
    # Print the totals row
    logger.info("-" * 100)
    logger.info(f"{'TOTAL':<30} {summary['total_lines_extracted']:<8} {summary['tag_counts']['TEXT']:<8} {summary['tag_counts']['FORM']:<8} {summary['tag_counts']['TABLE']:<8} {text_avg:<10.2f} {form_avg:<10.2f} {table_avg:<10.2f}")
    
    # Save the complete summary as JSON
    summary_file = os.path.join(output_dir, "full_summary.json")
    with open(summary_file, 'w', encoding='utf-8') as f:
        json.dump(summary, f, indent=2)
    logger.info(f"Complete summary saved to {summary_file}")
        
    return summary

if __name__ == "__main__":
    # Example usage - modify these paths as needed
    input_directory = "problem2"
    output_directory = "problem2_output"
    
    # Process all files
    summary = process_directory(input_directory, output_directory)
# Out:
# 2025-03-22 15:49:31,258 - INFO - Created problem2_output/document_part_classification_278_lines.txt with 9 lines
# 2025-03-22 15:49:31,259 - INFO - Created problem2_output/document_part_classification_522_lines.txt with 34 lines
# 2025-03-22 15:49:31,260 - INFO - Created problem2_output/document_part_classification_244_lines.txt with 21 lines
# 2025-03-22 15:49:31,261 - INFO - Created problem2_output/document_part_classification_250_lines.txt with 16 lines
# 2025-03-22 15:49:31,262 - INFO - Created problem2_output/document_part_classification_536_lines.txt with 29 lines
# 2025-03-22 15:49:31,263 - INFO - Created problem2_output/document_part_classification_287_lines.txt with 15 lines
# 2025-03-22 15:49:31,264 - INFO - Created problem2_output/document_part_classification_293_lines.txt with 5 lines
# 2025-03-22 15:49:31,265 - INFO - Created problem2_output/document_part_classification_132_lines.txt with 6 lines
# 2025-03-22 15:49:31,266 - INFO - Created problem2_output/document_part_classification_654_lines.txt with 23 lines
# 2025-03-22 15:49:31,267 - INFO - Created problem2_output/document_part_classification_67_lines.txt with 28 lines
# 2025-03-22 15:49:31,268 - INFO - Created problem2_output/document_part_classification_640_lines.txt with 6 lines
# 2025-03-22 15:49:31,269 - INFO - Created problem2_output/document_part_classification_73_lines.txt with 6 lines
# 2025-03-22 15:49:31,270 - INFO - Created problem2_output/document_part_classification_126_lines.txt with 2 lines
# 2025-03-22 15:49:31,271 - INFO - Created problem2_output/document_part_classification_98_lines.txt with 11 lines
# 2025-03-22 15:49:31,272 - INFO - Created problem2_output/document_part_classification_318_lines.txt with 28 lines
# 2025-03-22 15:49:31,273 - INFO - Created problem2_output/document_part_classification_456_lines.txt with 42 lines
# 2025-03-22 15:49:31,274 - INFO - Created problem2_output/document_part_classification_330_lines.txt with 18 lines
# 2025-03-22 15:49:31,275 - INFO - Created problem2_output/document_part_classification_324_lines.txt with 25 lines
# 2025-03-22 15:49:31,276 - INFO - Created problem2_output/document_part_classification_442_lines.txt with 13 lines
# 2025-03-22 15:49:31,277 - INFO - Created problem2_output/document_part_classification_495_lines.txt with 28 lines
# 2025-03-22 15:49:31,278 - INFO - Created problem2_output/document_part_classification_481_lines.txt with 8 lines
# 2025-03-22 15:49:31,279 - INFO - Created problem2_output/document_part_classification_480_lines.txt with 11 lines
# 2025-03-22 15:49:31,279 - INFO - Created problem2_output/document_part_classification_494_lines.txt with 14 lines
# 2025-03-22 15:49:31,280 - INFO - Created problem2_output/document_part_classification_325_lines.txt with 21 lines
# 2025-03-22 15:49:31,280 - INFO - Created problem2_output/document_part_classification_443_lines.txt with 14 lines
# 2025-03-22 15:49:31,281 - INFO - Created problem2_output/document_part_classification_457_lines.txt with 41 lines
# 2025-03-22 15:49:31,282 - INFO - Created problem2_output/document_part_classification_331_lines.txt with 8 lines
# 2025-03-22 15:49:31,283 - INFO - Created problem2_output/document_part_classification_319_lines.txt with 6 lines
# 2025-03-22 15:49:31,284 - INFO - Created problem2_output/document_part_classification_99_lines.txt with 50 lines
# 2025-03-22 15:49:31,285 - INFO - Created problem2_output/document_part_classification_72_lines.txt with 15 lines
# 2025-03-22 15:49:31,286 - INFO - Created problem2_output/document_part_classification_641_lines.txt with 3 lines
# 2025-03-22 15:49:31,286 - INFO - Created problem2_output/document_part_classification_127_lines.txt with 10 lines
# 2025-03-22 15:49:31,287 - INFO - Created problem2_output/document_part_classification_133_lines.txt with 40 lines
# 2025-03-22 15:49:31,288 - INFO - Created problem2_output/document_part_classification_66_lines.txt with 15 lines
# 2025-03-22 15:49:31,289 - INFO - Created problem2_output/document_part_classification_655_lines.txt with 39 lines
# 2025-03-22 15:49:31,290 - INFO - Created problem2_output/document_part_classification_292_lines.txt with 7 lines
# 2025-03-22 15:49:31,291 - INFO - Created problem2_output/document_part_classification_286_lines.txt with 22 lines
# 2025-03-22 15:49:31,291 - INFO - Created problem2_output/document_part_classification_251_lines.txt with 5 lines
# 2025-03-22 15:49:31,292 - INFO - Created problem2_output/document_part_classification_537_lines.txt with 17 lines
# 2025-03-22 15:49:31,293 - INFO - Created problem2_output/document_part_classification_523_lines.txt with 39 lines
# 2025-03-22 15:49:31,293 - INFO - Created problem2_output/document_part_classification_245_lines.txt with 14 lines
# 2025-03-22 15:49:31,294 - INFO - Created problem2_output/document_part_classification_279_lines.txt with 27 lines
# 2025-03-22 15:49:31,301 - INFO - Created problem2_output/document_part_classification_509_lines.txt with 15 lines
# 2025-03-22 15:49:31,302 - INFO - Created problem2_output/document_part_classification_535_lines.txt with 33 lines
# 2025-03-22 15:49:31,303 - INFO - Created problem2_output/document_part_classification_253_lines.txt with 7 lines
# 2025-03-22 15:49:31,304 - INFO - Created problem2_output/document_part_classification_247_lines.txt with 15 lines
# 2025-03-22 15:49:31,304 - INFO - Created problem2_output/document_part_classification_521_lines.txt with 37 lines
# 2025-03-22 15:49:31,305 - INFO - Created problem2_output/document_part_classification_290_lines.txt with 29 lines
# 2025-03-22 15:49:31,306 - INFO - Created problem2_output/document_part_classification_284_lines.txt with 12 lines
# 2025-03-22 15:49:31,306 - INFO - Created problem2_output/document_part_classification_119_lines.txt with 14 lines
# 2025-03-22 15:49:31,307 - INFO - Created problem2_output/document_part_classification_58_lines.txt with 7 lines
# 2025-03-22 15:49:31,308 - INFO - Created problem2_output/document_part_classification_125_lines.txt with 31 lines
# 2025-03-22 15:49:31,309 - INFO - Created problem2_output/document_part_classification_643_lines.txt with 32 lines
# 2025-03-22 15:49:31,309 - INFO - Created problem2_output/document_part_classification_70_lines.txt with 15 lines
# 2025-03-22 15:49:31,310 - INFO - Created problem2_output/document_part_classification_64_lines.txt with 20 lines
# 2025-03-22 15:49:31,311 - INFO - Created problem2_output/document_part_classification_131_lines.txt with 6 lines
# 2025-03-22 15:49:31,311 - INFO - Created problem2_output/document_part_classification_469_lines.txt with 8 lines
# 2025-03-22 15:49:31,312 - INFO - Created problem2_output/document_part_classification_441_lines.txt with 18 lines
# 2025-03-22 15:49:31,312 - INFO - Created problem2_output/document_part_classification_327_lines.txt with 32 lines
# 2025-03-22 15:49:31,313 - INFO - Created problem2_output/document_part_classification_333_lines.txt with 16 lines
# 2025-03-22 15:49:31,314 - INFO - Created problem2_output/document_part_classification_455_lines.txt with 7 lines
# 2025-03-22 15:49:31,315 - INFO - Created problem2_output/document_part_classification_482_lines.txt with 5 lines
# 2025-03-22 15:49:31,315 - INFO - Created problem2_output/document_part_classification_496_lines.txt with 8 lines
# 2025-03-22 15:49:31,316 - INFO - Created problem2_output/document_part_classification_497_lines.txt with 12 lines
# 2025-03-22 15:49:31,317 - INFO - Created problem2_output/document_part_classification_483_lines.txt with 37 lines
# 2025-03-22 15:49:31,318 - INFO - Created problem2_output/document_part_classification_332_lines.txt with 4 lines
# 2025-03-22 15:49:31,319 - INFO - Created problem2_output/document_part_classification_454_lines.txt with 46 lines
# 2025-03-22 15:49:31,320 - INFO - Created problem2_output/document_part_classification_440_lines.txt with 14 lines
# 2025-03-22 15:49:31,320 - INFO - Created problem2_output/document_part_classification_326_lines.txt with 13 lines
# 2025-03-22 15:49:31,321 - INFO - Created problem2_output/document_part_classification_468_lines.txt with 25 lines
# 2025-03-22 15:49:31,322 - INFO - Created problem2_output/document_part_classification_65_lines.txt with 10 lines
# 2025-03-22 15:49:31,322 - INFO - Created problem2_output/document_part_classification_656_lines.txt with 7 lines
# 2025-03-22 15:49:31,323 - INFO - Created problem2_output/document_part_classification_130_lines.txt with 6 lines
# 2025-03-22 15:49:31,323 - INFO - Created problem2_output/document_part_classification_124_lines.txt with 15 lines
# 2025-03-22 15:49:31,324 - INFO - Created problem2_output/document_part_classification_71_lines.txt with 20 lines
# 2025-03-22 15:49:31,325 - INFO - Created problem2_output/document_part_classification_642_lines.txt with 7 lines
# 2025-03-22 15:49:31,325 - INFO - Created problem2_output/document_part_classification_59_lines.txt with 8 lines
# 2025-03-22 15:49:31,326 - INFO - Created problem2_output/document_part_classification_118_lines.txt with 7 lines
# 2025-03-22 15:49:31,326 - INFO - Created problem2_output/document_part_classification_285_lines.txt with 17 lines
# 2025-03-22 15:49:31,327 - INFO - Created problem2_output/document_part_classification_291_lines.txt with 3 lines
# 2025-03-22 15:49:31,327 - INFO - Created problem2_output/document_part_classification_246_lines.txt with 11 lines
# 2025-03-22 15:49:31,328 - INFO - Created problem2_output/document_part_classification_520_lines.txt with 31 lines
# 2025-03-22 15:49:31,329 - INFO - Created problem2_output/document_part_classification_534_lines.txt with 15 lines
# 2025-03-22 15:49:31,329 - INFO - Created problem2_output/document_part_classification_252_lines.txt with 13 lines
# 2025-03-22 15:49:31,330 - INFO - Created problem2_output/document_part_classification_508_lines.txt with 18 lines
# 2025-03-22 15:49:31,330 - INFO - Created problem2_output/document_part_classification_256_lines.txt with 4 lines
# 2025-03-22 15:49:31,331 - INFO - Created problem2_output/document_part_classification_530_lines.txt with 6 lines
# 2025-03-22 15:49:31,332 - INFO - Created problem2_output/document_part_classification_524_lines.txt with 34 lines
# 2025-03-22 15:49:31,332 - INFO - Created problem2_output/document_part_classification_242_lines.txt with 21 lines
# 2025-03-22 15:49:31,333 - INFO - Created problem2_output/document_part_classification_518_lines.txt with 27 lines
# 2025-03-22 15:49:31,333 - INFO - Created problem2_output/document_part_classification_295_lines.txt with 14 lines
# 2025-03-22 15:49:31,334 - INFO - Created problem2_output/document_part_classification_281_lines.txt with 4 lines
# 2025-03-22 15:49:31,334 - INFO - Created problem2_output/document_part_classification_75_lines.txt with 17 lines
# 2025-03-22 15:49:31,335 - INFO - Created problem2_output/document_part_classification_646_lines.txt with 19 lines
# 2025-03-22 15:49:31,336 - INFO - Created problem2_output/document_part_classification_120_lines.txt with 44 lines
# 2025-03-22 15:49:31,336 - INFO - Created problem2_output/document_part_classification_134_lines.txt with 6 lines
# 2025-03-22 15:49:31,337 - INFO - Created problem2_output/document_part_classification_61_lines.txt with 12 lines
# 2025-03-22 15:49:31,338 - INFO - Created problem2_output/document_part_classification_652_lines.txt with 27 lines
# 2025-03-22 15:49:31,338 - INFO - Created problem2_output/document_part_classification_49_lines.txt with 14 lines
# 2025-03-22 15:49:31,339 - INFO - Created problem2_output/document_part_classification_108_lines.txt with 13 lines
# 2025-03-22 15:49:31,340 - INFO - Created problem2_output/document_part_classification_322_lines.txt with 30 lines
# 2025-03-22 15:49:31,340 - INFO - Created problem2_output/document_part_classification_444_lines.txt with 24 lines
# 2025-03-22 15:49:31,341 - INFO - Created problem2_output/document_part_classification_450_lines.txt with 35 lines
# 2025-03-22 15:49:31,342 - INFO - Created problem2_output/document_part_classification_336_lines.txt with 11 lines
# 2025-03-22 15:49:31,342 - INFO - Created problem2_output/document_part_classification_478_lines.txt with 27 lines
# 2025-03-22 15:49:31,343 - INFO - Created problem2_output/document_part_classification_487_lines.txt with 48 lines
# 2025-03-22 15:49:31,344 - INFO - Created problem2_output/document_part_classification_493_lines.txt with 50 lines
# 2025-03-22 15:49:31,344 - INFO - Created problem2_output/document_part_classification_492_lines.txt with 56 lines
# 2025-03-22 15:49:31,345 - INFO - Created problem2_output/document_part_classification_486_lines.txt with 24 lines
# 2025-03-22 15:49:31,345 - INFO - Created problem2_output/document_part_classification_479_lines.txt with 12 lines
# 2025-03-22 15:49:31,347 - INFO - Created problem2_output/document_part_classification_451_lines.txt with 26 lines
# 2025-03-22 15:49:31,348 - INFO - Created problem2_output/document_part_classification_337_lines.txt with 11 lines
# 2025-03-22 15:49:31,349 - INFO - Created problem2_output/document_part_classification_323_lines.txt with 12 lines
# 2025-03-22 15:49:31,350 - INFO - Created problem2_output/document_part_classification_445_lines.txt with 26 lines
# 2025-03-22 15:49:31,350 - INFO - Created problem2_output/document_part_classification_109_lines.txt with 16 lines
# 2025-03-22 15:49:31,351 - INFO - Created problem2_output/document_part_classification_48_lines.txt with 18 lines
# 2025-03-22 15:49:31,351 - INFO - Created problem2_output/document_part_classification_135_lines.txt with 10 lines
# 2025-03-22 15:49:31,352 - INFO - Created problem2_output/document_part_classification_653_lines.txt with 4 lines
# 2025-03-22 15:49:31,353 - INFO - Created problem2_output/document_part_classification_60_lines.txt with 6 lines
# 2025-03-22 15:49:31,353 - INFO - Created problem2_output/document_part_classification_647_lines.txt with 19 lines
# 2025-03-22 15:49:31,354 - INFO - Created problem2_output/document_part_classification_74_lines.txt with 21 lines
# 2025-03-22 15:49:31,354 - INFO - Created problem2_output/document_part_classification_121_lines.txt with 13 lines
# 2025-03-22 15:49:31,355 - INFO - Created problem2_output/document_part_classification_280_lines.txt with 19 lines
# 2025-03-22 15:49:31,356 - INFO - Created problem2_output/document_part_classification_294_lines.txt with 22 lines
# 2025-03-22 15:49:31,356 - INFO - Created problem2_output/document_part_classification_519_lines.txt with 21 lines
# 2025-03-22 15:49:31,357 - INFO - Created problem2_output/document_part_classification_525_lines.txt with 44 lines
# 2025-03-22 15:49:31,357 - INFO - Created problem2_output/document_part_classification_243_lines.txt with 32 lines
# 2025-03-22 15:49:31,358 - INFO - Created problem2_output/document_part_classification_257_lines.txt with 3 lines
# 2025-03-22 15:49:31,359 - INFO - Created problem2_output/document_part_classification_531_lines.txt with 38 lines
# 2025-03-22 15:49:31,359 - INFO - Created problem2_output/document_part_classification_241_lines.txt with 16 lines
# 2025-03-22 15:49:31,360 - INFO - Created problem2_output/document_part_classification_527_lines.txt with 28 lines
# 2025-03-22 15:49:31,360 - INFO - Created problem2_output/document_part_classification_533_lines.txt with 15 lines
# 2025-03-22 15:49:31,361 - INFO - Created problem2_output/document_part_classification_255_lines.txt with 15 lines
# 2025-03-22 15:49:31,362 - INFO - Created problem2_output/document_part_classification_269_lines.txt with 17 lines
# 2025-03-22 15:49:31,362 - INFO - Created problem2_output/document_part_classification_282_lines.txt with 17 lines
# 2025-03-22 15:49:31,363 - INFO - Created problem2_output/document_part_classification_296_lines.txt with 2 lines
# 2025-03-22 15:49:31,364 - INFO - Created problem2_output/document_part_classification_62_lines.txt with 35 lines
# 2025-03-22 15:49:31,365 - INFO - Created problem2_output/document_part_classification_651_lines.txt with 16 lines
# 2025-03-22 15:49:31,365 - INFO - Created problem2_output/document_part_classification_137_lines.txt with 16 lines
# 2025-03-22 15:49:31,366 - INFO - Created problem2_output/document_part_classification_123_lines.txt with 11 lines
# 2025-03-22 15:49:31,366 - INFO - Created problem2_output/document_part_classification_76_lines.txt with 30 lines
# 2025-03-22 15:49:31,367 - INFO - Created problem2_output/document_part_classification_645_lines.txt with 11 lines
# 2025-03-22 15:49:31,368 - INFO - Created problem2_output/document_part_classification_89_lines.txt with 14 lines
# 2025-03-22 15:49:31,369 - INFO - Created problem2_output/document_part_classification_335_lines.txt with 54 lines
# 2025-03-22 15:49:31,369 - INFO - Created problem2_output/document_part_classification_453_lines.txt with 21 lines
# 2025-03-22 15:49:31,370 - INFO - Created problem2_output/document_part_classification_447_lines.txt with 18 lines
# 2025-03-22 15:49:31,371 - INFO - Created problem2_output/document_part_classification_321_lines.txt with 3 lines
# 2025-03-22 15:49:31,371 - INFO - Created problem2_output/document_part_classification_309_lines.txt with 26 lines
# 2025-03-22 15:49:31,372 - INFO - Created problem2_output/document_part_classification_490_lines.txt with 52 lines
# 2025-03-22 15:49:31,373 - INFO - Created problem2_output/document_part_classification_484_lines.txt with 100 lines
# 2025-03-22 15:49:31,374 - INFO - Created problem2_output/document_part_classification_485_lines.txt with 14 lines
# 2025-03-22 15:49:31,374 - INFO - Created problem2_output/document_part_classification_491_lines.txt with 18 lines
# 2025-03-22 15:49:31,375 - INFO - Created problem2_output/document_part_classification_308_lines.txt with 48 lines
# 2025-03-22 15:49:31,376 - INFO - Created problem2_output/document_part_classification_446_lines.txt with 42 lines
# 2025-03-22 15:49:31,376 - INFO - Created problem2_output/document_part_classification_320_lines.txt with 59 lines
# 2025-03-22 15:49:31,377 - INFO - Created problem2_output/document_part_classification_334_lines.txt with 21 lines
# 2025-03-22 15:49:31,377 - INFO - Created problem2_output/document_part_classification_452_lines.txt with 21 lines
# 2025-03-22 15:49:31,378 - INFO - Created problem2_output/document_part_classification_88_lines.txt with 19 lines
# 2025-03-22 15:49:31,379 - INFO - Created problem2_output/document_part_classification_122_lines.txt with 8 lines
# 2025-03-22 15:49:31,381 - INFO - Created problem2_output/document_part_classification_644_lines.txt with 16 lines
# 2025-03-22 15:49:31,382 - INFO - Created problem2_output/document_part_classification_77_lines.txt with 12 lines
# 2025-03-22 15:49:31,383 - INFO - Created problem2_output/document_part_classification_650_lines.txt with 33 lines
# 2025-03-22 15:49:31,384 - INFO - Created problem2_output/document_part_classification_63_lines.txt with 14 lines
# 2025-03-22 15:49:31,386 - INFO - Created problem2_output/document_part_classification_136_lines.txt with 21 lines
# 2025-03-22 15:49:31,387 - INFO - Created problem2_output/document_part_classification_297_lines.txt with 28 lines
# 2025-03-22 15:49:31,388 - INFO - Created problem2_output/document_part_classification_283_lines.txt with 4 lines
# 2025-03-22 15:49:31,388 - INFO - Created problem2_output/document_part_classification_268_lines.txt with 14 lines
# 2025-03-22 15:49:31,389 - INFO - Created problem2_output/document_part_classification_532_lines.txt with 22 lines
# 2025-03-22 15:49:31,390 - INFO - Created problem2_output/document_part_classification_254_lines.txt with 4 lines
# 2025-03-22 15:49:31,390 - INFO - Created problem2_output/document_part_classification_240_lines.txt with 17 lines
# 2025-03-22 15:49:31,391 - INFO - Created problem2_output/document_part_classification_526_lines.txt with 8 lines
# 2025-03-22 15:49:31,392 - INFO - Created problem2_output/document_part_classification_569_lines.txt with 13 lines
# 2025-03-22 15:49:31,392 - INFO - Created problem2_output/document_part_classification_227_lines.txt with 12 lines
# 2025-03-22 15:49:31,393 - INFO - Created problem2_output/document_part_classification_541_lines.txt with 33 lines
# 2025-03-22 15:49:31,394 - INFO - Created problem2_output/document_part_classification_555_lines.txt with 50 lines
# 2025-03-22 15:49:31,394 - INFO - Created problem2_output/document_part_classification_233_lines.txt with 26 lines
# 2025-03-22 15:49:31,395 - INFO - Created problem2_output/document_part_classification_582_lines.txt with 20 lines
# 2025-03-22 15:49:31,396 - INFO - Created problem2_output/document_part_classification_596_lines.txt with 29 lines
# 2025-03-22 15:49:31,397 - INFO - Created problem2_output/document_part_classification_38_lines.txt with 7 lines
# 2025-03-22 15:49:31,398 - INFO - Created problem2_output/document_part_classification_179_lines.txt with 25 lines
# 2025-03-22 15:49:31,398 - INFO - Created problem2_output/document_part_classification_637_lines.txt with 24 lines
# 2025-03-22 15:49:31,399 - INFO - Created problem2_output/document_part_classification_151_lines.txt with 18 lines
# 2025-03-22 15:49:31,400 - INFO - Created problem2_output/document_part_classification_145_lines.txt with 29 lines
# 2025-03-22 15:49:31,400 - INFO - Created problem2_output/document_part_classification_623_lines.txt with 2 lines
# 2025-03-22 15:49:31,401 - INFO - Created problem2_output/document_part_classification_10_lines.txt with 14 lines
# 2025-03-22 15:49:31,402 - INFO - Created problem2_output/document_part_classification_192_lines.txt with 22 lines
# 2025-03-22 15:49:31,402 - INFO - Created problem2_output/document_part_classification_186_lines.txt with 6 lines
# 2025-03-22 15:49:31,403 - INFO - Created problem2_output/document_part_classification_409_lines.txt with 5 lines
# 2025-03-22 15:49:31,404 - INFO - Created problem2_output/document_part_classification_353_lines.txt with 7 lines
# 2025-03-22 15:49:31,404 - INFO - Created problem2_output/document_part_classification_435_lines.txt with 37 lines
# 2025-03-22 15:49:31,405 - INFO - Created problem2_output/document_part_classification_421_lines.txt with 21 lines
# 2025-03-22 15:49:31,405 - INFO - Created problem2_output/document_part_classification_347_lines.txt with 30 lines
# 2025-03-22 15:49:31,406 - INFO - Created problem2_output/document_part_classification_390_lines.txt with 8 lines
# 2025-03-22 15:49:31,407 - INFO - Created problem2_output/document_part_classification_384_lines.txt with 21 lines
# 2025-03-22 15:49:31,407 - INFO - Created problem2_output/document_part_classification_385_lines.txt with 15 lines
# 2025-03-22 15:49:31,408 - INFO - Created problem2_output/document_part_classification_391_lines.txt with 24 lines
# 2025-03-22 15:49:31,408 - INFO - Created problem2_output/document_part_classification_420_lines.txt with 5 lines
# 2025-03-22 15:49:31,409 - INFO - Created problem2_output/document_part_classification_346_lines.txt with 48 lines
# 2025-03-22 15:49:31,410 - INFO - Created problem2_output/document_part_classification_352_lines.txt with 46 lines
# 2025-03-22 15:49:31,410 - INFO - Created problem2_output/document_part_classification_434_lines.txt with 24 lines
# 2025-03-22 15:49:31,411 - INFO - Created problem2_output/document_part_classification_408_lines.txt with 2 lines
# 2025-03-22 15:49:31,412 - INFO - Created problem2_output/document_part_classification_187_lines.txt with 25 lines
# 2025-03-22 15:49:31,412 - INFO - Created problem2_output/document_part_classification_193_lines.txt with 29 lines
# 2025-03-22 15:49:31,413 - INFO - Created problem2_output/document_part_classification_144_lines.txt with 11 lines
# 2025-03-22 15:49:31,413 - INFO - Created problem2_output/document_part_classification_11_lines.txt with 6 lines
# 2025-03-22 15:49:31,414 - INFO - Created problem2_output/document_part_classification_622_lines.txt with 13 lines
# 2025-03-22 15:49:31,414 - INFO - Created problem2_output/document_part_classification_636_lines.txt with 12 lines
# 2025-03-22 15:49:31,415 - INFO - Created problem2_output/document_part_classification_150_lines.txt with 12 lines
# 2025-03-22 15:49:31,416 - INFO - Created problem2_output/document_part_classification_178_lines.txt with 21 lines
# 2025-03-22 15:49:31,416 - INFO - Created problem2_output/document_part_classification_39_lines.txt with 9 lines
# 2025-03-22 15:49:31,417 - INFO - Created problem2_output/document_part_classification_597_lines.txt with 8 lines
# 2025-03-22 15:49:31,417 - INFO - Created problem2_output/document_part_classification_583_lines.txt with 14 lines
# 2025-03-22 15:49:31,418 - INFO - Created problem2_output/document_part_classification_554_lines.txt with 21 lines
# 2025-03-22 15:49:31,419 - INFO - Created problem2_output/document_part_classification_232_lines.txt with 25 lines
# 2025-03-22 15:49:31,420 - INFO - Created problem2_output/document_part_classification_226_lines.txt with 15 lines
# 2025-03-22 15:49:31,420 - INFO - Created problem2_output/document_part_classification_540_lines.txt with 24 lines
# 2025-03-22 15:49:31,421 - INFO - Created problem2_output/document_part_classification_568_lines.txt with 27 lines
# 2025-03-22 15:49:31,422 - INFO - Created problem2_output/document_part_classification_218_lines.txt with 16 lines
# 2025-03-22 15:49:31,423 - INFO - Created problem2_output/document_part_classification_230_lines.txt with 16 lines
# 2025-03-22 15:49:31,424 - INFO - Created problem2_output/document_part_classification_556_lines.txt with 13 lines
# 2025-03-22 15:49:31,424 - INFO - Created problem2_output/document_part_classification_542_lines.txt with 29 lines
# 2025-03-22 15:49:31,425 - INFO - Created problem2_output/document_part_classification_224_lines.txt with 28 lines
# 2025-03-22 15:49:31,426 - INFO - Created problem2_output/document_part_classification_595_lines.txt with 8 lines
# 2025-03-22 15:49:31,427 - INFO - Created problem2_output/document_part_classification_581_lines.txt with 13 lines
# 2025-03-22 15:49:31,427 - INFO - Created problem2_output/document_part_classification_608_lines.txt with 18 lines
# 2025-03-22 15:49:31,428 - INFO - Created problem2_output/document_part_classification_620_lines.txt with 28 lines
# 2025-03-22 15:49:31,428 - INFO - Created problem2_output/document_part_classification_13_lines.txt with 11 lines
# 2025-03-22 15:49:31,429 - INFO - Created problem2_output/document_part_classification_146_lines.txt with 15 lines
# 2025-03-22 15:49:31,429 - INFO - Created problem2_output/document_part_classification_152_lines.txt with 16 lines
# 2025-03-22 15:49:31,430 - INFO - Created problem2_output/document_part_classification_634_lines.txt with 4 lines
# 2025-03-22 15:49:31,431 - INFO - Created problem2_output/document_part_classification_185_lines.txt with 22 lines
# 2025-03-22 15:49:31,431 - INFO - Created problem2_output/document_part_classification_191_lines.txt with 3 lines
# 2025-03-22 15:49:31,432 - INFO - Created problem2_output/document_part_classification_378_lines.txt with 40 lines
# 2025-03-22 15:49:31,433 - INFO - Created problem2_output/document_part_classification_344_lines.txt with 23 lines
# 2025-03-22 15:49:31,433 - INFO - Created problem2_output/document_part_classification_422_lines.txt with 40 lines
# 2025-03-22 15:49:31,434 - INFO - Created problem2_output/document_part_classification_436_lines.txt with 21 lines
# 2025-03-22 15:49:31,435 - INFO - Created problem2_output/document_part_classification_350_lines.txt with 21 lines
# 2025-03-22 15:49:31,435 - INFO - Created problem2_output/document_part_classification_387_lines.txt with 28 lines
# 2025-03-22 15:49:31,436 - INFO - Created problem2_output/document_part_classification_393_lines.txt with 51 lines
# 2025-03-22 15:49:31,437 - INFO - Created problem2_output/document_part_classification_392_lines.txt with 23 lines
# 2025-03-22 15:49:31,437 - INFO - Created problem2_output/document_part_classification_386_lines.txt with 18 lines
# 2025-03-22 15:49:31,438 - INFO - Created problem2_output/document_part_classification_437_lines.txt with 46 lines
# 2025-03-22 15:49:31,439 - INFO - Created problem2_output/document_part_classification_351_lines.txt with 46 lines
# 2025-03-22 15:49:31,440 - INFO - Created problem2_output/document_part_classification_345_lines.txt with 9 lines
# 2025-03-22 15:49:31,440 - INFO - Created problem2_output/document_part_classification_423_lines.txt with 46 lines
# 2025-03-22 15:49:31,441 - INFO - Created problem2_output/document_part_classification_379_lines.txt with 32 lines
# 2025-03-22 15:49:31,442 - INFO - Created problem2_output/document_part_classification_190_lines.txt with 13 lines
# 2025-03-22 15:49:31,442 - INFO - Created problem2_output/document_part_classification_184_lines.txt with 7 lines
# 2025-03-22 15:49:31,443 - INFO - Created problem2_output/document_part_classification_153_lines.txt with 13 lines
# 2025-03-22 15:49:31,444 - INFO - Created problem2_output/document_part_classification_635_lines.txt with 25 lines
# 2025-03-22 15:49:31,445 - INFO - Created problem2_output/document_part_classification_12_lines.txt with 22 lines
# 2025-03-22 15:49:31,446 - INFO - Created problem2_output/document_part_classification_621_lines.txt with 24 lines
# 2025-03-22 15:49:31,446 - INFO - Created problem2_output/document_part_classification_147_lines.txt with 23 lines
# 2025-03-22 15:49:31,447 - INFO - Created problem2_output/document_part_classification_609_lines.txt with 17 lines
# 2025-03-22 15:49:31,448 - INFO - Created problem2_output/document_part_classification_580_lines.txt with 2 lines
# 2025-03-22 15:49:31,449 - INFO - Created problem2_output/document_part_classification_594_lines.txt with 4 lines
# 2025-03-22 15:49:31,449 - INFO - Created problem2_output/document_part_classification_543_lines.txt with 29 lines
# 2025-03-22 15:49:31,450 - INFO - Created problem2_output/document_part_classification_225_lines.txt with 11 lines
# 2025-03-22 15:49:31,451 - INFO - Created problem2_output/document_part_classification_231_lines.txt with 30 lines
# 2025-03-22 15:49:31,452 - INFO - Created problem2_output/document_part_classification_557_lines.txt with 22 lines
# 2025-03-22 15:49:31,453 - INFO - Created problem2_output/document_part_classification_219_lines.txt with 9 lines
# 2025-03-22 15:49:31,454 - INFO - Created problem2_output/document_part_classification_553_lines.txt with 11 lines
# 2025-03-22 15:49:31,455 - INFO - Created problem2_output/document_part_classification_235_lines.txt with 7 lines
# 2025-03-22 15:49:31,456 - INFO - Created problem2_output/document_part_classification_221_lines.txt with 9 lines
# 2025-03-22 15:49:31,457 - INFO - Created problem2_output/document_part_classification_547_lines.txt with 29 lines
# 2025-03-22 15:49:31,459 - INFO - Created problem2_output/document_part_classification_209_lines.txt with 13 lines
# 2025-03-22 15:49:31,461 - INFO - Created problem2_output/document_part_classification_590_lines.txt with 4 lines
# 2025-03-22 15:49:31,462 - INFO - Created problem2_output/document_part_classification_584_lines.txt with 5 lines
# 2025-03-22 15:49:31,462 - INFO - Created problem2_output/document_part_classification_143_lines.txt with 11 lines
# 2025-03-22 15:49:31,463 - INFO - Created problem2_output/document_part_classification_16_lines.txt with 17 lines
# 2025-03-22 15:49:31,464 - INFO - Created problem2_output/document_part_classification_625_lines.txt with 45 lines
# 2025-03-22 15:49:31,464 - INFO - Created problem2_output/document_part_classification_631_lines.txt with 17 lines
# 2025-03-22 15:49:31,465 - INFO - Created problem2_output/document_part_classification_157_lines.txt with 44 lines
# 2025-03-22 15:49:31,466 - INFO - Created problem2_output/document_part_classification_619_lines.txt with 19 lines
# 2025-03-22 15:49:31,467 - INFO - Created problem2_output/document_part_classification_9_lines.txt with 30 lines
# 2025-03-22 15:49:31,468 - INFO - Created problem2_output/document_part_classification_180_lines.txt with 15 lines
# 2025-03-22 15:49:31,468 - INFO - Created problem2_output/document_part_classification_194_lines.txt with 11 lines
# 2025-03-22 15:49:31,469 - INFO - Created problem2_output/document_part_classification_427_lines.txt with 17 lines
# 2025-03-22 15:49:31,470 - INFO - Created problem2_output/document_part_classification_341_lines.txt with 46 lines
# 2025-03-22 15:49:31,471 - INFO - Created problem2_output/document_part_classification_355_lines.txt with 41 lines
# 2025-03-22 15:49:31,471 - INFO - Created problem2_output/document_part_classification_433_lines.txt with 26 lines
# 2025-03-22 15:49:31,472 - INFO - Created problem2_output/document_part_classification_369_lines.txt with 15 lines
# 2025-03-22 15:49:31,473 - INFO - Created problem2_output/document_part_classification_382_lines.txt with 6 lines
# 2025-03-22 15:49:31,474 - INFO - Created problem2_output/document_part_classification_396_lines.txt with 24 lines
# 2025-03-22 15:49:31,474 - INFO - Created problem2_output/document_part_classification_397_lines.txt with 41 lines
# 2025-03-22 15:49:31,475 - INFO - Created problem2_output/document_part_classification_383_lines.txt with 30 lines
# 2025-03-22 15:49:31,476 - INFO - Created problem2_output/document_part_classification_368_lines.txt with 29 lines
# 2025-03-22 15:49:31,477 - INFO - Created problem2_output/document_part_classification_354_lines.txt with 42 lines
# 2025-03-22 15:49:31,478 - INFO - Created problem2_output/document_part_classification_432_lines.txt with 10 lines
# 2025-03-22 15:49:31,478 - INFO - Created problem2_output/document_part_classification_426_lines.txt with 8 lines
# 2025-03-22 15:49:31,479 - INFO - Created problem2_output/document_part_classification_340_lines.txt with 53 lines
# 2025-03-22 15:49:31,480 - INFO - Created problem2_output/document_part_classification_195_lines.txt with 32 lines
# 2025-03-22 15:49:31,483 - INFO - Created problem2_output/document_part_classification_181_lines.txt with 13 lines
# 2025-03-22 15:49:31,483 - INFO - Created problem2_output/document_part_classification_8_lines.txt with 8 lines
# 2025-03-22 15:49:31,484 - INFO - Created problem2_output/document_part_classification_618_lines.txt with 14 lines
# 2025-03-22 15:49:31,485 - INFO - Created problem2_output/document_part_classification_630_lines.txt with 8 lines
# 2025-03-22 15:49:31,485 - INFO - Created problem2_output/document_part_classification_156_lines.txt with 17 lines
# 2025-03-22 15:49:31,486 - INFO - Created problem2_output/document_part_classification_142_lines.txt with 11 lines
# 2025-03-22 15:49:31,486 - INFO - Created problem2_output/document_part_classification_624_lines.txt with 18 lines
# 2025-03-22 15:49:31,487 - INFO - Created problem2_output/document_part_classification_17_lines.txt with 35 lines
# 2025-03-22 15:49:31,488 - INFO - Created problem2_output/document_part_classification_585_lines.txt with 15 lines
# 2025-03-22 15:49:31,488 - INFO - Created problem2_output/document_part_classification_591_lines.txt with 11 lines
# 2025-03-22 15:49:31,489 - INFO - Created problem2_output/document_part_classification_208_lines.txt with 10 lines
# 2025-03-22 15:49:31,489 - INFO - Created problem2_output/document_part_classification_220_lines.txt with 3 lines
# 2025-03-22 15:49:31,490 - INFO - Created problem2_output/document_part_classification_546_lines.txt with 17 lines
# 2025-03-22 15:49:31,490 - INFO - Created problem2_output/document_part_classification_552_lines.txt with 30 lines
# 2025-03-22 15:49:31,491 - INFO - Created problem2_output/document_part_classification_234_lines.txt with 21 lines
# 2025-03-22 15:49:31,491 - INFO - Created problem2_output/document_part_classification_544_lines.txt with 6 lines
# 2025-03-22 15:49:31,492 - INFO - Created problem2_output/document_part_classification_222_lines.txt with 18 lines
# 2025-03-22 15:49:31,493 - INFO - Created problem2_output/document_part_classification_236_lines.txt with 16 lines
# 2025-03-22 15:49:31,493 - INFO - Created problem2_output/document_part_classification_550_lines.txt with 13 lines
# 2025-03-22 15:49:31,494 - INFO - Created problem2_output/document_part_classification_578_lines.txt with 8 lines
# 2025-03-22 15:49:31,495 - INFO - Created problem2_output/document_part_classification_587_lines.txt with 14 lines
# 2025-03-22 15:49:31,499 - INFO - Created problem2_output/document_part_classification_593_lines.txt with 28 lines
# 2025-03-22 15:49:31,499 - INFO - Created problem2_output/document_part_classification_154_lines.txt with 24 lines
# 2025-03-22 15:49:31,500 - INFO - Created problem2_output/document_part_classification_632_lines.txt with 26 lines
# 2025-03-22 15:49:31,501 - INFO - Created problem2_output/document_part_classification_15_lines.txt with 3 lines
# 2025-03-22 15:49:31,501 - INFO - Created problem2_output/document_part_classification_626_lines.txt with 19 lines
# 2025-03-22 15:49:31,502 - INFO - Created problem2_output/document_part_classification_140_lines.txt with 13 lines
# 2025-03-22 15:49:31,503 - INFO - Created problem2_output/document_part_classification_168_lines.txt with 16 lines
# 2025-03-22 15:49:31,503 - INFO - Created problem2_output/document_part_classification_29_lines.txt with 3 lines
# 2025-03-22 15:49:31,504 - INFO - Created problem2_output/document_part_classification_197_lines.txt with 11 lines
# 2025-03-22 15:49:31,505 - INFO - Created problem2_output/document_part_classification_183_lines.txt with 14 lines
# 2025-03-22 15:49:31,505 - INFO - Created problem2_output/document_part_classification_430_lines.txt with 10 lines
# 2025-03-22 15:49:31,506 - INFO - Created problem2_output/document_part_classification_356_lines.txt with 40 lines
# 2025-03-22 15:49:31,507 - INFO - Created problem2_output/document_part_classification_342_lines.txt with 31 lines
# 2025-03-22 15:49:31,508 - INFO - Created problem2_output/document_part_classification_424_lines.txt with 24 lines
# 2025-03-22 15:49:31,508 - INFO - Created problem2_output/document_part_classification_418_lines.txt with 35 lines
# 2025-03-22 15:49:31,509 - INFO - Created problem2_output/document_part_classification_395_lines.txt with 15 lines
# 2025-03-22 15:49:31,510 - INFO - Created problem2_output/document_part_classification_381_lines.txt with 14 lines
# 2025-03-22 15:49:31,511 - INFO - Created problem2_output/document_part_classification_380_lines.txt with 30 lines
# 2025-03-22 15:49:31,512 - INFO - Created problem2_output/document_part_classification_394_lines.txt with 5 lines
# 2025-03-22 15:49:31,513 - INFO - Created problem2_output/document_part_classification_419_lines.txt with 28 lines
# 2025-03-22 15:49:31,514 - INFO - Created problem2_output/document_part_classification_343_lines.txt with 27 lines
# 2025-03-22 15:49:31,515 - INFO - Created problem2_output/document_part_classification_425_lines.txt with 56 lines
# 2025-03-22 15:49:31,515 - INFO - Created problem2_output/document_part_classification_431_lines.txt with 20 lines
# 2025-03-22 15:49:31,516 - INFO - Created problem2_output/document_part_classification_357_lines.txt with 21 lines
# 2025-03-22 15:49:31,517 - INFO - Created problem2_output/document_part_classification_182_lines.txt with 23 lines
# 2025-03-22 15:49:31,519 - INFO - Created problem2_output/document_part_classification_196_lines.txt with 14 lines
# 2025-03-22 15:49:31,520 - INFO - Created problem2_output/document_part_classification_28_lines.txt with 13 lines
# 2025-03-22 15:49:31,521 - INFO - Created problem2_output/document_part_classification_169_lines.txt with 26 lines
# 2025-03-22 15:49:31,522 - INFO - Created problem2_output/document_part_classification_627_lines.txt with 3 lines
# 2025-03-22 15:49:31,522 - INFO - Created problem2_output/document_part_classification_14_lines.txt with 12 lines
# 2025-03-22 15:49:31,523 - INFO - Created problem2_output/document_part_classification_141_lines.txt with 11 lines
# 2025-03-22 15:49:31,524 - INFO - Created problem2_output/document_part_classification_155_lines.txt with 11 lines
# 2025-03-22 15:49:31,525 - INFO - Created problem2_output/document_part_classification_633_lines.txt with 14 lines
# 2025-03-22 15:49:31,526 - INFO - Created problem2_output/document_part_classification_592_lines.txt with 16 lines
# 2025-03-22 15:49:31,531 - INFO - Created problem2_output/document_part_classification_586_lines.txt with 19 lines
# 2025-03-22 15:49:31,532 - INFO - Created problem2_output/document_part_classification_579_lines.txt with 6 lines
# 2025-03-22 15:49:31,534 - INFO - Created problem2_output/document_part_classification_237_lines.txt with 39 lines
# 2025-03-22 15:49:31,534 - INFO - Created problem2_output/document_part_classification_551_lines.txt with 45 lines
# 2025-03-22 15:49:31,535 - INFO - Created problem2_output/document_part_classification_545_lines.txt with 29 lines
# 2025-03-22 15:49:31,537 - INFO - Created problem2_output/document_part_classification_223_lines.txt with 117 lines
# 2025-03-22 15:49:31,537 - INFO - Created problem2_output/document_part_classification_548_lines.txt with 27 lines
# 2025-03-22 15:49:31,538 - INFO - Created problem2_output/document_part_classification_206_lines.txt with 18 lines
# 2025-03-22 15:49:31,539 - INFO - Created problem2_output/document_part_classification_560_lines.txt with 14 lines
# 2025-03-22 15:49:31,540 - INFO - Created problem2_output/document_part_classification_574_lines.txt with 27 lines
# 2025-03-22 15:49:31,541 - INFO - Created problem2_output/document_part_classification_212_lines.txt with 6 lines
# 2025-03-22 15:49:31,542 - INFO - Created problem2_output/document_part_classification_19_lines.txt with 18 lines
# 2025-03-22 15:49:31,543 - INFO - Created problem2_output/document_part_classification_158_lines.txt with 14 lines
# 2025-03-22 15:49:31,544 - INFO - Created problem2_output/document_part_classification_616_lines.txt with 18 lines
# 2025-03-22 15:49:31,544 - INFO - Created problem2_output/document_part_classification_25_lines.txt with 17 lines
# 2025-03-22 15:49:31,545 - INFO - Created problem2_output/document_part_classification_170_lines.txt with 15 lines
# 2025-03-22 15:49:31,546 - INFO - Created problem2_output/document_part_classification_164_lines.txt with 25 lines
# 2025-03-22 15:49:31,546 - INFO - Created problem2_output/document_part_classification_6_lines.txt with 13 lines
# 2025-03-22 15:49:31,547 - INFO - Created problem2_output/document_part_classification_602_lines.txt with 14 lines
# 2025-03-22 15:49:31,550 - INFO - Created problem2_output/document_part_classification_31_lines.txt with 20 lines
# 2025-03-22 15:49:31,551 - INFO - Created problem2_output/document_part_classification_428_lines.txt with 16 lines
# 2025-03-22 15:49:31,551 - INFO - Created problem2_output/document_part_classification_372_lines.txt with 9 lines
# 2025-03-22 15:49:31,552 - INFO - Created problem2_output/document_part_classification_414_lines.txt with 78 lines
# 2025-03-22 15:49:31,553 - INFO - Created problem2_output/document_part_classification_400_lines.txt with 24 lines
# 2025-03-22 15:49:31,553 - INFO - Created problem2_output/document_part_classification_366_lines.txt with 19 lines
# 2025-03-22 15:49:31,554 - INFO - Created problem2_output/document_part_classification_399_lines.txt with 25 lines
# 2025-03-22 15:49:31,554 - INFO - Created problem2_output/document_part_classification_398_lines.txt with 38 lines
# 2025-03-22 15:49:31,555 - INFO - Created problem2_output/document_part_classification_401_lines.txt with 11 lines
# 2025-03-22 15:49:31,556 - INFO - Created problem2_output/document_part_classification_367_lines.txt with 5 lines
# 2025-03-22 15:49:31,556 - INFO - Created problem2_output/document_part_classification_373_lines.txt with 7 lines
# 2025-03-22 15:49:31,557 - INFO - Created problem2_output/document_part_classification_415_lines.txt with 23 lines
# 2025-03-22 15:49:31,557 - INFO - Created problem2_output/document_part_classification_429_lines.txt with 15 lines
# 2025-03-22 15:49:31,558 - INFO - Created problem2_output/document_part_classification_7_lines.txt with 37 lines
# 2025-03-22 15:49:31,558 - INFO - Created problem2_output/document_part_classification_165_lines.txt with 5 lines
# 2025-03-22 15:49:31,559 - INFO - Created problem2_output/document_part_classification_30_lines.txt with 34 lines
# 2025-03-22 15:49:31,559 - INFO - Created problem2_output/document_part_classification_603_lines.txt with 19 lines
# 2025-03-22 15:49:31,560 - INFO - Created problem2_output/document_part_classification_24_lines.txt with 17 lines
# 2025-03-22 15:49:31,561 - INFO - Created problem2_output/document_part_classification_617_lines.txt with 36 lines
# 2025-03-22 15:49:31,561 - INFO - Created problem2_output/document_part_classification_171_lines.txt with 7 lines
# 2025-03-22 15:49:31,562 - INFO - Created problem2_output/document_part_classification_159_lines.txt with 10 lines
# 2025-03-22 15:49:31,563 - INFO - Created problem2_output/document_part_classification_18_lines.txt with 8 lines
# 2025-03-22 15:49:31,563 - INFO - Created problem2_output/document_part_classification_575_lines.txt with 8 lines
# 2025-03-22 15:49:31,564 - INFO - Created problem2_output/document_part_classification_213_lines.txt with 14 lines
# 2025-03-22 15:49:31,565 - INFO - Created problem2_output/document_part_classification_207_lines.txt with 10 lines
# 2025-03-22 15:49:31,565 - INFO - Created problem2_output/document_part_classification_561_lines.txt with 37 lines
# 2025-03-22 15:49:31,566 - INFO - Created problem2_output/document_part_classification_549_lines.txt with 16 lines
# 2025-03-22 15:49:31,567 - INFO - Created problem2_output/document_part_classification_239_lines.txt with 9 lines
# 2025-03-22 15:49:31,568 - INFO - Created problem2_output/document_part_classification_211_lines.txt with 14 lines
# 2025-03-22 15:49:31,568 - INFO - Created problem2_output/document_part_classification_577_lines.txt with 4 lines
# 2025-03-22 15:49:31,569 - INFO - Created problem2_output/document_part_classification_563_lines.txt with 15 lines
# 2025-03-22 15:49:31,570 - INFO - Created problem2_output/document_part_classification_205_lines.txt with 8 lines
# 2025-03-22 15:49:31,571 - INFO - Created problem2_output/document_part_classification_588_lines.txt with 4 lines
# 2025-03-22 15:49:31,571 - INFO - Created problem2_output/document_part_classification_629_lines.txt with 27 lines
# 2025-03-22 15:49:31,572 - INFO - Created problem2_output/document_part_classification_601_lines.txt with 19 lines
# 2025-03-22 15:49:31,573 - INFO - Created problem2_output/document_part_classification_32_lines.txt with 22 lines
# 2025-03-22 15:49:31,574 - INFO - Created problem2_output/document_part_classification_167_lines.txt with 33 lines
# 2025-03-22 15:49:31,574 - INFO - Created problem2_output/document_part_classification_5_lines.txt with 27 lines
# 2025-03-22 15:49:31,575 - INFO - Created problem2_output/document_part_classification_173_lines.txt with 9 lines
# 2025-03-22 15:49:31,576 - INFO - Created problem2_output/document_part_classification_615_lines.txt with 5 lines
# 2025-03-22 15:49:31,577 - INFO - Created problem2_output/document_part_classification_26_lines.txt with 20 lines
# 2025-03-22 15:49:31,578 - INFO - Created problem2_output/document_part_classification_198_lines.txt with 15 lines
# 2025-03-22 15:49:31,578 - INFO - Created problem2_output/document_part_classification_359_lines.txt with 3 lines
# 2025-03-22 15:49:31,580 - INFO - Created problem2_output/document_part_classification_365_lines.txt with 29 lines
# 2025-03-22 15:49:31,580 - INFO - Created problem2_output/document_part_classification_403_lines.txt with 16 lines
# 2025-03-22 15:49:31,581 - INFO - Created problem2_output/document_part_classification_417_lines.txt with 25 lines
# 2025-03-22 15:49:31,582 - INFO - Created problem2_output/document_part_classification_371_lines.txt with 3 lines
# 2025-03-22 15:49:31,583 - INFO - Created problem2_output/document_part_classification_416_lines.txt with 15 lines
# 2025-03-22 15:49:31,584 - INFO - Created problem2_output/document_part_classification_370_lines.txt with 6 lines
# 2025-03-22 15:49:31,586 - INFO - Created problem2_output/document_part_classification_364_lines.txt with 14 lines
# 2025-03-22 15:49:31,589 - INFO - Created problem2_output/document_part_classification_402_lines.txt with 4 lines
# 2025-03-22 15:49:31,589 - INFO - Created problem2_output/document_part_classification_358_lines.txt with 25 lines
# 2025-03-22 15:49:31,590 - INFO - Created problem2_output/document_part_classification_199_lines.txt with 12 lines
# 2025-03-22 15:49:31,591 - INFO - Created problem2_output/document_part_classification_172_lines.txt with 8 lines
# 2025-03-22 15:49:31,592 - INFO - Created problem2_output/document_part_classification_27_lines.txt with 6 lines
# 2025-03-22 15:49:31,593 - INFO - Created problem2_output/document_part_classification_614_lines.txt with 5 lines
# ...
# 2025-03-22 15:49:31,905 - INFO - document_part_classification_59.xml 8        0        8        0        0.00       47.38      0.00
# 2025-03-22 15:49:31,905 - INFO - document_part_classification_590.xml 4        1        3        0        317.00     31.33      0.00
# 2025-03-22 15:49:31,905 - INFO - document_part_classification_591.xml 11       3        8        0        568.00     41.75      0.00
# 2025-03-22 15:49:31,905 - INFO - document_part_classification_592.xml 16       2        14       0        490.50     82.29      0.00
# 2025-03-22 15:49:31,905 - INFO - document_part_classification_593.xml 28       1        0        27       396.00     0.00       44.22
# 2025-03-22 15:49:31,906 - INFO - document_part_classification_594.xml 4        3        1        0        709.00     155.00     0.00
# 2025-03-22 15:49:31,906 - INFO - document_part_classification_595.xml 8        3        5        0        616.00     62.40      0.00
# 2025-03-22 15:49:31,906 - INFO - document_part_classification_596.xml 29       0        0        29       0.00       0.00       71.90
# 2025-03-22 15:49:31,906 - INFO - document_part_classification_597.xml 8        3        5        0        821.67     58.60      0.00
# 2025-03-22 15:49:31,906 - INFO - document_part_classification_598.xml 12       3        9        0        1408.00    84.89      0.00
# 2025-03-22 15:49:31,906 - INFO - document_part_classification_599.xml 23       4        19       0        333.75     61.95      0.00
# 2025-03-22 15:49:31,907 - INFO - document_part_classification_6.xml 13       0        13       0        0.00       19.31      0.00
# 2025-03-22 15:49:31,907 - INFO - document_part_classification_60.xml 6        0        6        0        0.00       46.33      0.00
# 2025-03-22 15:49:31,907 - INFO - document_part_classification_600.xml 7        3        4        0        407.00     66.75      0.00
# 2025-03-22 15:49:31,907 - INFO - document_part_classification_601.xml 19       2        17       0        428.50     77.53      0.00
# 2025-03-22 15:49:31,908 - INFO - document_part_classification_602.xml 14       2        12       0        411.50     95.83      0.00
# 2025-03-22 15:49:31,908 - INFO - document_part_classification_603.xml 19       0        15       4        0.00       34.53      79.00
# 2025-03-22 15:49:31,908 - INFO - document_part_classification_604.xml 16       0        16       0        0.00       69.81      0.00
# 2025-03-22 15:49:31,908 - INFO - document_part_classification_605.xml 16       0        16       0        0.00       58.81      0.00
# 2025-03-22 15:49:31,908 - INFO - document_part_classification_606.xml 7        0        7        0        0.00       57.29      0.00
# 2025-03-22 15:49:31,908 - INFO - document_part_classification_607.xml 21       1        20       0        297.00     65.40      0.00
# 2025-03-22 15:49:31,909 - INFO - document_part_classification_608.xml 18       0        18       0        0.00       42.61      0.00
# 2025-03-22 15:49:31,909 - INFO - document_part_classification_609.xml 17       0        17       0        0.00       50.24      0.00
# 2025-03-22 15:49:31,909 - INFO - document_part_classification_61.xml 12       0        12       0        0.00       55.50      0.00
# 2025-03-22 15:49:31,909 - INFO - document_part_classification_610.xml 16       0        16       0        0.00       48.81      0.00
# 2025-03-22 15:49:31,909 - INFO - document_part_classification_611.xml 15       0        15       0        0.00       20.80      0.00
# 2025-03-22 15:49:31,909 - INFO - document_part_classification_612.xml 21       0        21       0        0.00       70.24      0.00
# 2025-03-22 15:49:31,910 - INFO - document_part_classification_613.xml 10       0        10       0        0.00       75.10      0.00
# 2025-03-22 15:49:31,910 - INFO - document_part_classification_614.xml 5        1        4        0        207.00     63.50      0.00
# 2025-03-22 15:49:31,910 - INFO - document_part_classification_615.xml 5        0        5        0        0.00       72.80      0.00
# 2025-03-22 15:49:31,911 - INFO - document_part_classification_616.xml 18       1        17       0        448.00     83.94      0.00
# 2025-03-22 15:49:31,911 - INFO - document_part_classification_617.xml 36       0        36       0        0.00       78.06      0.00
# 2025-03-22 15:49:31,911 - INFO - document_part_classification_618.xml 14       1        13       0        260.00     47.69      0.00
# 2025-03-22 15:49:31,911 - INFO - document_part_classification_619.xml 19       2        17       0        249.00     54.41      0.00
# 2025-03-22 15:49:31,912 - INFO - document_part_classification_62.xml 35       0        35       0        0.00       91.51      0.00
# 2025-03-22 15:49:31,912 - INFO - document_part_classification_620.xml 28       0        28       0        0.00       78.89      0.00
# 2025-03-22 15:49:31,912 - INFO - document_part_classification_621.xml 24       0        24       0        0.00       41.88      0.00
# 2025-03-22 15:49:31,912 - INFO - document_part_classification_622.xml 13       1        12       0        492.00     66.58      0.00
# 2025-03-22 15:49:31,912 - INFO - document_part_classification_623.xml 2        0        2        0        0.00       59.00      0.00
# 2025-03-22 15:49:31,912 - INFO - document_part_classification_624.xml 18       1        17       0        1464.00    72.12      0.00
# 2025-03-22 15:49:31,913 - INFO - document_part_classification_625.xml 45       2        43       0        568.00     55.07      0.00
# 2025-03-22 15:49:31,913 - INFO - document_part_classification_626.xml 19       2        17       0        315.00     79.76      0.00
# 2025-03-22 15:49:31,913 - INFO - document_part_classification_627.xml 3        0        3        0        0.00       44.00      0.00
# 2025-03-22 15:49:31,913 - INFO - document_part_classification_628.xml 3        0        3        0        0.00       77.33      0.00
# 2025-03-22 15:49:31,913 - INFO - document_part_classification_629.xml 27       1        26       0        365.00     47.46      0.00
# 2025-03-22 15:49:31,914 - INFO - document_part_classification_63.xml 14       2        12       0        269.00     50.83      0.00
# 2025-03-22 15:49:31,914 - INFO - document_part_classification_630.xml 8        1        7        0        424.00     69.00      0.00
# 2025-03-22 15:49:31,914 - INFO - document_part_classification_631.xml 17       1        16       0        291.00     102.12     0.00
# 2025-03-22 15:49:31,914 - INFO - document_part_classification_632.xml 26       2        24       0        320.00     66.17      0.00
# 2025-03-22 15:49:31,914 - INFO - document_part_classification_633.xml 14       0        14       0        0.00       54.21      0.00
# 2025-03-22 15:49:31,914 - INFO - document_part_classification_634.xml 4        0        4        0        0.00       65.50      0.00
# 2025-03-22 15:49:31,915 - INFO - document_part_classification_635.xml 25       9        16       0        371.67     88.50      0.00
# 2025-03-22 15:49:31,915 - INFO - document_part_classification_636.xml 12       3        9        0        567.33     83.89      0.00
# 2025-03-22 15:49:31,915 - INFO - document_part_classification_637.xml 24       4        20       0        354.00     127.05     0.00
# 2025-03-22 15:49:31,915 - INFO - document_part_classification_638.xml 12       1        11       0        648.00     45.36      0.00
# 2025-03-22 15:49:31,915 - INFO - document_part_classification_639.xml 16       0        16       0        0.00       23.50      0.00
# 2025-03-22 15:49:31,915 - INFO - document_part_classification_64.xml 20       1        19       0        374.00     95.37      0.00
# 2025-03-22 15:49:31,916 - INFO - document_part_classification_640.xml 6        0        6        0        0.00       48.17      0.00
# 2025-03-22 15:49:31,916 - INFO - document_part_classification_641.xml 3        1        2        0        365.00     41.00      0.00
# 2025-03-22 15:49:31,916 - INFO - document_part_classification_642.xml 7        0        7        0        0.00       65.43      0.00
# 2025-03-22 15:49:31,916 - INFO - document_part_classification_643.xml 32       8        24       0        459.50     62.75      0.00
# 2025-03-22 15:49:31,916 - INFO - document_part_classification_644.xml 16       4        3        9        562.25     65.00      33.67
# 2025-03-22 15:49:31,917 - INFO - document_part_classification_645.xml 11       0        11       0        0.00       61.09      0.00
# 2025-03-22 15:49:31,917 - INFO - document_part_classification_646.xml 19       3        16       0        421.00     87.38      0.00
# 2025-03-22 15:49:31,917 - INFO - document_part_classification_647.xml 19       0        19       0        0.00       97.53      0.00
# 2025-03-22 15:49:31,917 - INFO - document_part_classification_648.xml 13       0        13       0        0.00       33.38      0.00
# 2025-03-22 15:49:31,917 - INFO - document_part_classification_649.xml 16       1        15       0        581.00     51.00      0.00
# 2025-03-22 15:49:31,917 - INFO - document_part_classification_65.xml 10       3        7        0        441.00     69.29      0.00
# 2025-03-22 15:49:31,918 - INFO - document_part_classification_650.xml 33       3        30       0        430.33     78.50      0.00
# 2025-03-22 15:49:31,920 - INFO - document_part_classification_651.xml 16       2        14       0        284.50     57.43      0.00
# 2025-03-22 15:49:31,920 - INFO - document_part_classification_652.xml 27       0        27       0        0.00       53.56      0.00
# 2025-03-22 15:49:31,920 - INFO - document_part_classification_653.xml 4        2        2        0        616.00     108.00     0.00
# 2025-03-22 15:49:31,921 - INFO - document_part_classification_654.xml 23       0        23       0        0.00       95.13      0.00
# 2025-03-22 15:49:31,921 - INFO - document_part_classification_655.xml 39       3        36       0        584.33     88.08      0.00
# 2025-03-22 15:49:31,975 - INFO - document_part_classification_656.xml 7        0        7        0        0.00       65.57      0.00
# 2025-03-22 15:49:31,975 - INFO - document_part_classification_66.xml 15       0        15       0        0.00       73.60      0.00
# 2025-03-22 15:49:31,975 - INFO - document_part_classification_67.xml 28       0        0        28       0.00       0.00       78.50
# 2025-03-22 15:49:31,976 - INFO - document_part_classification_68.xml 10       0        10       0        0.00       53.30      0.00
# 2025-03-22 15:49:31,976 - INFO - document_part_classification_69.xml 6        0        6        0        0.00       30.00      0.00
# 2025-03-22 15:49:31,976 - INFO - document_part_classification_7.xml 37       1        36       0        1601.00    148.50     0.00
# 2025-03-22 15:49:31,976 - INFO - document_part_classification_70.xml 15       4        11       0        412.75     33.00      0.00
# 2025-03-22 15:49:31,976 - INFO - document_part_classification_71.xml 20       0        20       0        0.00       61.20      0.00
# 2025-03-22 15:49:31,976 - INFO - document_part_classification_72.xml 15       3        12       0        555.33     64.83      0.00
# 2025-03-22 15:49:31,977 - INFO - document_part_classification_73.xml 6        2        4        0        298.50     63.75      0.00
# 2025-03-22 15:49:31,977 - INFO - document_part_classification_74.xml 21       0        21       0        0.00       47.33      0.00
# 2025-03-22 15:49:31,977 - INFO - document_part_classification_75.xml 17       1        16       0        627.00     77.62      0.00
# 2025-03-22 15:49:31,977 - INFO - document_part_classification_76.xml 30       0        30       0        0.00       46.53      0.00
# 2025-03-22 15:49:31,977 - INFO - document_part_classification_77.xml 12       0        12       0        0.00       48.33      0.00
# 2025-03-22 15:49:31,978 - INFO - document_part_classification_78.xml 41       0        41       0        0.00       74.90      0.00
# 2025-03-22 15:49:31,978 - INFO - document_part_classification_79.xml 8        2        6        0        606.00     89.00      0.00
# 2025-03-22 15:49:31,978 - INFO - document_part_classification_8.xml 8        1        7        0        262.00     46.43      0.00
# 2025-03-22 15:49:31,978 - INFO - document_part_classification_80.xml 7        1        6        0        270.00     35.33      0.00
# 2025-03-22 15:49:31,979 - INFO - document_part_classification_81.xml 15       3        12       0        389.33     62.00      0.00
# 2025-03-22 15:49:31,979 - INFO - document_part_classification_82.xml 32       0        0        32       0.00       0.00       90.34
# 2025-03-22 15:49:31,979 - INFO - document_part_classification_83.xml 6        2        4        0        315.50     31.25      0.00
# 2025-03-22 15:49:31,979 - INFO - document_part_classification_84.xml 28       0        28       0        0.00       62.61      0.00
# 2025-03-22 15:49:31,979 - INFO - document_part_classification_85.xml 6        1        5        0        495.00     53.00      0.00
# 2025-03-22 15:49:31,979 - INFO - document_part_classification_86.xml 117      3        25       89       380.33     51.80      95.73
# 2025-03-22 15:49:31,979 - INFO - document_part_classification_87.xml 26       5        21       0        581.20     71.05      0.00
# 2025-03-22 15:49:31,980 - INFO - document_part_classification_88.xml 19       3        16       0        421.33     81.31      0.00
# 2025-03-22 15:49:31,980 - INFO - document_part_classification_89.xml 14       1        13       0        289.00     70.85      0.00
# 2025-03-22 15:49:31,980 - INFO - document_part_classification_9.xml 30       0        30       0        0.00       82.70      0.00
# 2025-03-22 15:49:31,980 - INFO - document_part_classification_90.xml 6        0        6        0        0.00       69.00      0.00
# 2025-03-22 15:49:31,980 - INFO - document_part_classification_91.xml 14       0        14       0        0.00       45.64      0.00
# 2025-03-22 15:49:31,981 - INFO - document_part_classification_92.xml 3        0        3        0        0.00       37.00      0.00
# 2025-03-22 15:49:31,981 - INFO - document_part_classification_93.xml 23       2        21       0        589.00     68.90      0.00
# 2025-03-22 15:49:31,981 - INFO - document_part_classification_94.xml 21       0        21       0        0.00       72.00      0.00
# 2025-03-22 15:49:31,981 - INFO - document_part_classification_95.xml 3        1        2        0        499.00     62.00      0.00
# 2025-03-22 15:49:31,981 - INFO - document_part_classification_96.xml 8        1        7        0        272.00     64.00      0.00
# 2025-03-22 15:49:31,982 - INFO - document_part_classification_97.xml 18       1        17       0        301.00     35.59      0.00
# 2025-03-22 15:49:31,982 - INFO - document_part_classification_98.xml 11       0        11       0        0.00       45.64      0.00
# 2025-03-22 15:49:31,982 - INFO - document_part_classification_99.xml 50       0        50       0        0.00       23.80      0.00
# 2025-03-22 15:49:31,982 - INFO - ----------------------------------------------------------------------------------------------------
# 2025-03-22 15:49:31,982 - INFO - TOTAL                          12852    891      7437     4524     639.12     65.58      83.60
# 2025-03-22 15:49:31,991 - INFO - Complete summary saved to problem2_output/full_summary.json

# %%
summary
# Out:
# {'files_processed': 656,
#  'files_with_content': 656,
#  'total_lines_extracted': 12852,
#  'tag_counts': {'TEXT': 891, 'FORM': 7437, 'TABLE': 4524},
#  'char_counts': {'TEXT': 569453, 'FORM': 487687, 'TABLE': 378186},
#  'skipped_tags': {'SECTION_HEADER': 595,
#   'PAGE_FOOTER': 363,
#   'UNSPECIFIED': 645,
#   'PAGE_HEADER': 162,
#   'TITLE': 328,
#   'CAPTION': 61},
#  'per_document_stats': [{'filename': 'document_part_classification_1.xml',
#    'total_lines': 26,
#    'TEXT_lines': 1,
#    'FORM_lines': 25,
#    'TABLE_lines': 0,
#    'TEXT_chars': 435,
#    'FORM_chars': 1542,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 435.0,
#    'FORM_avg_len': 61.68,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_10.xml',
#    'total_lines': 14,
#    'TEXT_lines': 3,
#    'FORM_lines': 11,
#    'TABLE_lines': 0,
#    'TEXT_chars': 2595,
#    'FORM_chars': 610,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 865.0,
#    'FORM_avg_len': 55.45454545454545,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_100.xml',
#    'total_lines': 24,
#    'TEXT_lines': 0,
#    'FORM_lines': 24,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1800,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 75.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_101.xml',
#    'total_lines': 17,
#    'TEXT_lines': 5,
#    'FORM_lines': 12,
#    'TABLE_lines': 0,
#    'TEXT_chars': 2683,
#    'FORM_chars': 1013,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 536.6,
#    'FORM_avg_len': 84.41666666666667,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_102.xml',
#    'total_lines': 12,
#    'TEXT_lines': 0,
#    'FORM_lines': 12,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 888,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 74.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_103.xml',
#    'total_lines': 2,
#    'TEXT_lines': 0,
#    'FORM_lines': 2,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 155,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 77.5,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_104.xml',
#    'total_lines': 21,
#    'TEXT_lines': 0,
#    'FORM_lines': 21,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1164,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 55.42857142857143,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_105.xml',
#    'total_lines': 21,
#    'TEXT_lines': 3,
#    'FORM_lines': 18,
#    'TABLE_lines': 0,
#    'TEXT_chars': 2240,
#    'FORM_chars': 1394,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 746.6666666666666,
#    'FORM_avg_len': 77.44444444444444,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_106.xml',
#    'total_lines': 11,
#    'TEXT_lines': 0,
#    'FORM_lines': 11,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 721,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 65.54545454545455,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_107.xml',
#    'total_lines': 24,
#    'TEXT_lines': 0,
#    'FORM_lines': 24,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1071,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 44.625,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_108.xml',
#    'total_lines': 13,
#    'TEXT_lines': 0,
#    'FORM_lines': 13,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 391,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 30.076923076923077,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_109.xml',
#    'total_lines': 16,
#    'TEXT_lines': 0,
#    'FORM_lines': 16,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 791,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 49.4375,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_11.xml',
#    'total_lines': 6,
#    'TEXT_lines': 0,
#    'FORM_lines': 6,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 432,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 72.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_110.xml',
#    'total_lines': 29,
#    'TEXT_lines': 1,
#    'FORM_lines': 28,
#    'TABLE_lines': 0,
#    'TEXT_chars': 2532,
#    'FORM_chars': 2530,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 2532.0,
#    'FORM_avg_len': 90.35714285714286,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_111.xml',
#    'total_lines': 12,
#    'TEXT_lines': 2,
#    'FORM_lines': 10,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1151,
#    'FORM_chars': 708,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 575.5,
#    'FORM_avg_len': 70.8,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_112.xml',
#    'total_lines': 6,
#    'TEXT_lines': 1,
#    'FORM_lines': 5,
#    'TABLE_lines': 0,
#    'TEXT_chars': 465,
#    'FORM_chars': 287,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 465.0,
#    'FORM_avg_len': 57.4,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_113.xml',
#    'total_lines': 47,
#    'TEXT_lines': 1,
#    'FORM_lines': 46,
#    'TABLE_lines': 0,
#    'TEXT_chars': 646,
#    'FORM_chars': 3163,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 646.0,
#    'FORM_avg_len': 68.76086956521739,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_114.xml',
#    'total_lines': 3,
#    'TEXT_lines': 1,
#    'FORM_lines': 2,
#    'TABLE_lines': 0,
#    'TEXT_chars': 681,
#    'FORM_chars': 110,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 681.0,
#    'FORM_avg_len': 55.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_115.xml',
#    'total_lines': 29,
#    'TEXT_lines': 2,
#    'FORM_lines': 27,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1880,
#    'FORM_chars': 2091,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 940.0,
#    'FORM_avg_len': 77.44444444444444,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_116.xml',
#    'total_lines': 53,
#    'TEXT_lines': 0,
#    'FORM_lines': 53,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 3857,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 72.77358490566037,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_117.xml',
#    'total_lines': 5,
#    'TEXT_lines': 0,
#    'FORM_lines': 5,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 296,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 59.2,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_118.xml',
#    'total_lines': 7,
#    'TEXT_lines': 0,
#    'FORM_lines': 7,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 246,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 35.142857142857146,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_119.xml',
#    'total_lines': 14,
#    'TEXT_lines': 0,
#    'FORM_lines': 14,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 437,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 31.214285714285715,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_12.xml',
#    'total_lines': 22,
#    'TEXT_lines': 5,
#    'FORM_lines': 17,
#    'TABLE_lines': 0,
#    'TEXT_chars': 4426,
#    'FORM_chars': 633,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 885.2,
#    'FORM_avg_len': 37.23529411764706,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_120.xml',
#    'total_lines': 44,
#    'TEXT_lines': 0,
#    'FORM_lines': 44,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 2426,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 55.13636363636363,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_121.xml',
#    'total_lines': 13,
#    'TEXT_lines': 0,
#    'FORM_lines': 13,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 582,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 44.76923076923077,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_122.xml',
#    'total_lines': 8,
#    'TEXT_lines': 0,
#    'FORM_lines': 8,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 422,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 52.75,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_123.xml',
#    'total_lines': 11,
#    'TEXT_lines': 3,
#    'FORM_lines': 8,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1690,
#    'FORM_chars': 655,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 563.3333333333334,
#    'FORM_avg_len': 81.875,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_124.xml',
#    'total_lines': 15,
#    'TEXT_lines': 4,
#    'FORM_lines': 11,
#    'TABLE_lines': 0,
#    'TEXT_chars': 2324,
#    'FORM_chars': 914,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 581.0,
#    'FORM_avg_len': 83.0909090909091,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_125.xml',
#    'total_lines': 31,
#    'TEXT_lines': 0,
#    'FORM_lines': 31,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1880,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 60.645161290322584,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_126.xml',
#    'total_lines': 2,
#    'TEXT_lines': 0,
#    'FORM_lines': 2,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 185,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 92.5,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_127.xml',
#    'total_lines': 10,
#    'TEXT_lines': 4,
#    'FORM_lines': 6,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1701,
#    'FORM_chars': 543,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 425.25,
#    'FORM_avg_len': 90.5,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_128.xml',
#    'total_lines': 32,
#    'TEXT_lines': 0,
#    'FORM_lines': 32,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 2188,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 68.375,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_129.xml',
#    'total_lines': 8,
#    'TEXT_lines': 1,
#    'FORM_lines': 7,
#    'TABLE_lines': 0,
#    'TEXT_chars': 295,
#    'FORM_chars': 525,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 295.0,
#    'FORM_avg_len': 75.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_13.xml',
#    'total_lines': 11,
#    'TEXT_lines': 1,
#    'FORM_lines': 10,
#    'TABLE_lines': 0,
#    'TEXT_chars': 475,
#    'FORM_chars': 422,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 475.0,
#    'FORM_avg_len': 42.2,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_130.xml',
#    'total_lines': 6,
#    'TEXT_lines': 1,
#    'FORM_lines': 5,
#    'TABLE_lines': 0,
#    'TEXT_chars': 340,
#    'FORM_chars': 374,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 340.0,
#    'FORM_avg_len': 74.8,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_131.xml',
#    'total_lines': 6,
#    'TEXT_lines': 0,
#    'FORM_lines': 6,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 321,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 53.5,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_132.xml',
#    'total_lines': 6,
#    'TEXT_lines': 0,
#    'FORM_lines': 6,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 360,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 60.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_133.xml',
#    'total_lines': 40,
#    'TEXT_lines': 2,
#    'FORM_lines': 38,
#    'TABLE_lines': 0,
#    'TEXT_chars': 2250,
#    'FORM_chars': 3192,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 1125.0,
#    'FORM_avg_len': 84.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_134.xml',
#    'total_lines': 6,
#    'TEXT_lines': 1,
#    'FORM_lines': 5,
#    'TABLE_lines': 0,
#    'TEXT_chars': 815,
#    'FORM_chars': 333,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 815.0,
#    'FORM_avg_len': 66.6,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_135.xml',
#    'total_lines': 10,
#    'TEXT_lines': 1,
#    'FORM_lines': 9,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1242,
#    'FORM_chars': 411,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 1242.0,
#    'FORM_avg_len': 45.666666666666664,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_136.xml',
#    'total_lines': 21,
#    'TEXT_lines': 0,
#    'FORM_lines': 21,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1127,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 53.666666666666664,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_137.xml',
#    'total_lines': 16,
#    'TEXT_lines': 1,
#    'FORM_lines': 15,
#    'TABLE_lines': 0,
#    'TEXT_chars': 339,
#    'FORM_chars': 942,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 339.0,
#    'FORM_avg_len': 62.8,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_138.xml',
#    'total_lines': 9,
#    'TEXT_lines': 1,
#    'FORM_lines': 8,
#    'TABLE_lines': 0,
#    'TEXT_chars': 726,
#    'FORM_chars': 659,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 726.0,
#    'FORM_avg_len': 82.375,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_139.xml',
#    'total_lines': 13,
#    'TEXT_lines': 1,
#    'FORM_lines': 12,
#    'TABLE_lines': 0,
#    'TEXT_chars': 360,
#    'FORM_chars': 351,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 360.0,
#    'FORM_avg_len': 29.25,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_14.xml',
#    'total_lines': 12,
#    'TEXT_lines': 1,
#    'FORM_lines': 11,
#    'TABLE_lines': 0,
#    'TEXT_chars': 935,
#    'FORM_chars': 613,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 935.0,
#    'FORM_avg_len': 55.72727272727273,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_140.xml',
#    'total_lines': 13,
#    'TEXT_lines': 2,
#    'FORM_lines': 11,
#    'TABLE_lines': 0,
#    'TEXT_chars': 521,
#    'FORM_chars': 654,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 260.5,
#    'FORM_avg_len': 59.45454545454545,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_141.xml',
#    'total_lines': 11,
#    'TEXT_lines': 4,
#    'FORM_lines': 7,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1906,
#    'FORM_chars': 409,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 476.5,
#    'FORM_avg_len': 58.42857142857143,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_142.xml',
#    'total_lines': 11,
#    'TEXT_lines': 3,
#    'FORM_lines': 8,
#    'TABLE_lines': 0,
#    'TEXT_chars': 2616,
#    'FORM_chars': 1591,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 872.0,
#    'FORM_avg_len': 198.875,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_143.xml',
#    'total_lines': 11,
#    'TEXT_lines': 0,
#    'FORM_lines': 11,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 591,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 53.72727272727273,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_144.xml',
#    'total_lines': 11,
#    'TEXT_lines': 0,
#    'FORM_lines': 11,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 796,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 72.36363636363636,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_145.xml',
#    'total_lines': 29,
#    'TEXT_lines': 0,
#    'FORM_lines': 29,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1818,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 62.689655172413794,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_146.xml',
#    'total_lines': 15,
#    'TEXT_lines': 0,
#    'FORM_lines': 15,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 966,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 64.4,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_147.xml',
#    'total_lines': 23,
#    'TEXT_lines': 0,
#    'FORM_lines': 23,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1636,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 71.1304347826087,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_148.xml',
#    'total_lines': 5,
#    'TEXT_lines': 1,
#    'FORM_lines': 4,
#    'TABLE_lines': 0,
#    'TEXT_chars': 345,
#    'FORM_chars': 117,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 345.0,
#    'FORM_avg_len': 29.25,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_149.xml',
#    'total_lines': 10,
#    'TEXT_lines': 2,
#    'FORM_lines': 8,
#    'TABLE_lines': 0,
#    'TEXT_chars': 976,
#    'FORM_chars': 556,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 488.0,
#    'FORM_avg_len': 69.5,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_15.xml',
#    'total_lines': 3,
#    'TEXT_lines': 2,
#    'FORM_lines': 1,
#    'TABLE_lines': 0,
#    'TEXT_chars': 878,
#    'FORM_chars': 79,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 439.0,
#    'FORM_avg_len': 79.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_150.xml',
#    'total_lines': 12,
#    'TEXT_lines': 2,
#    'FORM_lines': 10,
#    'TABLE_lines': 0,
#    'TEXT_chars': 774,
#    'FORM_chars': 818,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 387.0,
#    'FORM_avg_len': 81.8,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_151.xml',
#    'total_lines': 18,
#    'TEXT_lines': 0,
#    'FORM_lines': 18,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 732,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 40.666666666666664,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_152.xml',
#    'total_lines': 16,
#    'TEXT_lines': 0,
#    'FORM_lines': 16,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 719,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 44.9375,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_153.xml',
#    'total_lines': 13,
#    'TEXT_lines': 2,
#    'FORM_lines': 11,
#    'TABLE_lines': 0,
#    'TEXT_chars': 678,
#    'FORM_chars': 418,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 339.0,
#    'FORM_avg_len': 38.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_154.xml',
#    'total_lines': 24,
#    'TEXT_lines': 0,
#    'FORM_lines': 24,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1020,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 42.5,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_155.xml',
#    'total_lines': 11,
#    'TEXT_lines': 1,
#    'FORM_lines': 10,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1693,
#    'FORM_chars': 619,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 1693.0,
#    'FORM_avg_len': 61.9,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_156.xml',
#    'total_lines': 17,
#    'TEXT_lines': 0,
#    'FORM_lines': 17,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 780,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 45.88235294117647,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_157.xml',
#    'total_lines': 44,
#    'TEXT_lines': 5,
#    'FORM_lines': 39,
#    'TABLE_lines': 0,
#    'TEXT_chars': 2687,
#    'FORM_chars': 2868,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 537.4,
#    'FORM_avg_len': 73.53846153846153,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_158.xml',
#    'total_lines': 14,
#    'TEXT_lines': 5,
#    'FORM_lines': 9,
#    'TABLE_lines': 0,
#    'TEXT_chars': 3177,
#    'FORM_chars': 942,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 635.4,
#    'FORM_avg_len': 104.66666666666667,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_159.xml',
#    'total_lines': 10,
#    'TEXT_lines': 1,
#    'FORM_lines': 9,
#    'TABLE_lines': 0,
#    'TEXT_chars': 411,
#    'FORM_chars': 517,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 411.0,
#    'FORM_avg_len': 57.44444444444444,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_16.xml',
#    'total_lines': 17,
#    'TEXT_lines': 0,
#    'FORM_lines': 17,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1176,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 69.17647058823529,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_160.xml',
#    'total_lines': 13,
#    'TEXT_lines': 1,
#    'FORM_lines': 12,
#    'TABLE_lines': 0,
#    'TEXT_chars': 287,
#    'FORM_chars': 1048,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 287.0,
#    'FORM_avg_len': 87.33333333333333,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_161.xml',
#    'total_lines': 5,
#    'TEXT_lines': 0,
#    'FORM_lines': 5,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 269,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 53.8,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_162.xml',
#    'total_lines': 6,
#    'TEXT_lines': 0,
#    'FORM_lines': 6,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 319,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 53.166666666666664,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_163.xml',
#    'total_lines': 5,
#    'TEXT_lines': 2,
#    'FORM_lines': 3,
#    'TABLE_lines': 0,
#    'TEXT_chars': 3441,
#    'FORM_chars': 248,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 1720.5,
#    'FORM_avg_len': 82.66666666666667,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_164.xml',
#    'total_lines': 25,
#    'TEXT_lines': 0,
#    'FORM_lines': 25,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 710,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 28.4,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_165.xml',
#    'total_lines': 5,
#    'TEXT_lines': 1,
#    'FORM_lines': 4,
#    'TABLE_lines': 0,
#    'TEXT_chars': 265,
#    'FORM_chars': 348,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 265.0,
#    'FORM_avg_len': 87.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_166.xml',
#    'total_lines': 9,
#    'TEXT_lines': 3,
#    'FORM_lines': 6,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1538,
#    'FORM_chars': 385,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 512.6666666666666,
#    'FORM_avg_len': 64.16666666666667,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_167.xml',
#    'total_lines': 33,
#    'TEXT_lines': 0,
#    'FORM_lines': 33,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1972,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 59.75757575757576,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_168.xml',
#    'total_lines': 16,
#    'TEXT_lines': 5,
#    'FORM_lines': 11,
#    'TABLE_lines': 0,
#    'TEXT_chars': 4686,
#    'FORM_chars': 531,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 937.2,
#    'FORM_avg_len': 48.27272727272727,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_169.xml',
#    'total_lines': 26,
#    'TEXT_lines': 1,
#    'FORM_lines': 25,
#    'TABLE_lines': 0,
#    'TEXT_chars': 511,
#    'FORM_chars': 2316,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 511.0,
#    'FORM_avg_len': 92.64,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_17.xml',
#    'total_lines': 35,
#    'TEXT_lines': 0,
#    'FORM_lines': 35,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1520,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 43.42857142857143,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_170.xml',
#    'total_lines': 15,
#    'TEXT_lines': 0,
#    'FORM_lines': 15,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 940,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 62.666666666666664,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_171.xml',
#    'total_lines': 7,
#    'TEXT_lines': 2,
#    'FORM_lines': 5,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1057,
#    'FORM_chars': 239,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 528.5,
#    'FORM_avg_len': 47.8,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_172.xml',
#    'total_lines': 8,
#    'TEXT_lines': 1,
#    'FORM_lines': 7,
#    'TABLE_lines': 0,
#    'TEXT_chars': 325,
#    'FORM_chars': 393,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 325.0,
#    'FORM_avg_len': 56.142857142857146,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_173.xml',
#    'total_lines': 9,
#    'TEXT_lines': 0,
#    'FORM_lines': 9,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 633,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 70.33333333333333,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_174.xml',
#    'total_lines': 22,
#    'TEXT_lines': 0,
#    'FORM_lines': 22,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1785,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 81.13636363636364,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_175.xml',
#    'total_lines': 8,
#    'TEXT_lines': 0,
#    'FORM_lines': 8,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 2537,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 317.125,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_176.xml',
#    'total_lines': 4,
#    'TEXT_lines': 0,
#    'FORM_lines': 4,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 246,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 61.5,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_177.xml',
#    'total_lines': 5,
#    'TEXT_lines': 0,
#    'FORM_lines': 5,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 464,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 92.8,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_178.xml',
#    'total_lines': 21,
#    'TEXT_lines': 0,
#    'FORM_lines': 21,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1239,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 59.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_179.xml',
#    'total_lines': 25,
#    'TEXT_lines': 0,
#    'FORM_lines': 25,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1265,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 50.6,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_18.xml',
#    'total_lines': 8,
#    'TEXT_lines': 0,
#    'FORM_lines': 8,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 410,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 51.25,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_180.xml',
#    'total_lines': 15,
#    'TEXT_lines': 1,
#    'FORM_lines': 14,
#    'TABLE_lines': 0,
#    'TEXT_chars': 315,
#    'FORM_chars': 1147,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 315.0,
#    'FORM_avg_len': 81.92857142857143,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_181.xml',
#    'total_lines': 13,
#    'TEXT_lines': 0,
#    'FORM_lines': 13,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1199,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 92.23076923076923,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_182.xml',
#    'total_lines': 23,
#    'TEXT_lines': 1,
#    'FORM_lines': 22,
#    'TABLE_lines': 0,
#    'TEXT_chars': 230,
#    'FORM_chars': 2018,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 230.0,
#    'FORM_avg_len': 91.72727272727273,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_183.xml',
#    'total_lines': 14,
#    'TEXT_lines': 0,
#    'FORM_lines': 14,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 348,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 24.857142857142858,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_184.xml',
#    'total_lines': 7,
#    'TEXT_lines': 0,
#    'FORM_lines': 7,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 384,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 54.857142857142854,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_185.xml',
#    'total_lines': 22,
#    'TEXT_lines': 0,
#    'FORM_lines': 22,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 397,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 18.045454545454547,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_186.xml',
#    'total_lines': 6,
#    'TEXT_lines': 1,
#    'FORM_lines': 5,
#    'TABLE_lines': 0,
#    'TEXT_chars': 587,
#    'FORM_chars': 382,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 587.0,
#    'FORM_avg_len': 76.4,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_187.xml',
#    'total_lines': 25,
#    'TEXT_lines': 0,
#    'FORM_lines': 25,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1060,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 42.4,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_188.xml',
#    'total_lines': 26,
#    'TEXT_lines': 0,
#    'FORM_lines': 26,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 2169,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 83.42307692307692,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_189.xml',
#    'total_lines': 11,
#    'TEXT_lines': 0,
#    'FORM_lines': 11,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 394,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 35.81818181818182,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_19.xml',
#    'total_lines': 18,
#    'TEXT_lines': 3,
#    'FORM_lines': 15,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1678,
#    'FORM_chars': 818,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 559.3333333333334,
#    'FORM_avg_len': 54.53333333333333,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_190.xml',
#    'total_lines': 13,
#    'TEXT_lines': 0,
#    'FORM_lines': 13,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1296,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 99.6923076923077,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_191.xml',
#    'total_lines': 3,
#    'TEXT_lines': 1,
#    'FORM_lines': 2,
#    'TABLE_lines': 0,
#    'TEXT_chars': 483,
#    'FORM_chars': 124,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 483.0,
#    'FORM_avg_len': 62.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_192.xml',
#    'total_lines': 22,
#    'TEXT_lines': 0,
#    'FORM_lines': 22,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 370,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 16.818181818181817,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_193.xml',
#    'total_lines': 29,
#    'TEXT_lines': 0,
#    'FORM_lines': 29,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1235,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 42.58620689655172,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_194.xml',
#    'total_lines': 11,
#    'TEXT_lines': 0,
#    'FORM_lines': 11,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 452,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 41.09090909090909,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_195.xml',
#    'total_lines': 32,
#    'TEXT_lines': 0,
#    'FORM_lines': 32,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 2008,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 62.75,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_196.xml',
#    'total_lines': 14,
#    'TEXT_lines': 0,
#    'FORM_lines': 14,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 629,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 44.92857142857143,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_197.xml',
#    'total_lines': 11,
#    'TEXT_lines': 2,
#    'FORM_lines': 9,
#    'TABLE_lines': 0,
#    'TEXT_chars': 686,
#    'FORM_chars': 609,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 343.0,
#    'FORM_avg_len': 67.66666666666667,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_198.xml',
#    'total_lines': 15,
#    'TEXT_lines': 3,
#    'FORM_lines': 12,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1339,
#    'FORM_chars': 712,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 446.3333333333333,
#    'FORM_avg_len': 59.333333333333336,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_199.xml',
#    'total_lines': 12,
#    'TEXT_lines': 0,
#    'FORM_lines': 12,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 367,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 30.583333333333332,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_2.xml',
#    'total_lines': 24,
#    'TEXT_lines': 0,
#    'FORM_lines': 24,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1311,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 54.625,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_20.xml',
#    'total_lines': 5,
#    'TEXT_lines': 1,
#    'FORM_lines': 4,
#    'TABLE_lines': 0,
#    'TEXT_chars': 696,
#    'FORM_chars': 153,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 696.0,
#    'FORM_avg_len': 38.25,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_200.xml',
#    'total_lines': 6,
#    'TEXT_lines': 2,
#    'FORM_lines': 4,
#    'TABLE_lines': 0,
#    'TEXT_chars': 634,
#    'FORM_chars': 290,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 317.0,
#    'FORM_avg_len': 72.5,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_201.xml',
#    'total_lines': 6,
#    'TEXT_lines': 1,
#    'FORM_lines': 5,
#    'TABLE_lines': 0,
#    'TEXT_chars': 340,
#    'FORM_chars': 374,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 340.0,
#    'FORM_avg_len': 74.8,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_202.xml',
#    'total_lines': 9,
#    'TEXT_lines': 3,
#    'FORM_lines': 6,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1954,
#    'FORM_chars': 560,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 651.3333333333334,
#    'FORM_avg_len': 93.33333333333333,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_203.xml',
#    'total_lines': 13,
#    'TEXT_lines': 4,
#    'FORM_lines': 9,
#    'TABLE_lines': 0,
#    'TEXT_chars': 2556,
#    'FORM_chars': 584,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 639.0,
#    'FORM_avg_len': 64.88888888888889,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_204.xml',
#    'total_lines': 3,
#    'TEXT_lines': 0,
#    'FORM_lines': 3,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 196,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 65.33333333333333,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_205.xml',
#    'total_lines': 8,
#    'TEXT_lines': 0,
#    'FORM_lines': 8,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 513,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 64.125,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_206.xml',
#    'total_lines': 18,
#    'TEXT_lines': 0,
#    'FORM_lines': 18,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1210,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 67.22222222222223,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_207.xml',
#    'total_lines': 10,
#    'TEXT_lines': 0,
#    'FORM_lines': 10,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 576,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 57.6,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_208.xml',
#    'total_lines': 10,
#    'TEXT_lines': 1,
#    'FORM_lines': 9,
#    'TABLE_lines': 0,
#    'TEXT_chars': 452,
#    'FORM_chars': 937,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 452.0,
#    'FORM_avg_len': 104.11111111111111,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_209.xml',
#    'total_lines': 13,
#    'TEXT_lines': 2,
#    'FORM_lines': 11,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1128,
#    'FORM_chars': 656,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 564.0,
#    'FORM_avg_len': 59.63636363636363,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_21.xml',
#    'total_lines': 9,
#    'TEXT_lines': 1,
#    'FORM_lines': 8,
#    'TABLE_lines': 0,
#    'TEXT_chars': 855,
#    'FORM_chars': 272,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 855.0,
#    'FORM_avg_len': 34.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_210.xml',
#    'total_lines': 5,
#    'TEXT_lines': 1,
#    'FORM_lines': 4,
#    'TABLE_lines': 0,
#    'TEXT_chars': 256,
#    'FORM_chars': 300,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 256.0,
#    'FORM_avg_len': 75.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_211.xml',
#    'total_lines': 14,
#    'TEXT_lines': 0,
#    'FORM_lines': 14,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 559,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 39.92857142857143,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_212.xml',
#    'total_lines': 6,
#    'TEXT_lines': 1,
#    'FORM_lines': 5,
#    'TABLE_lines': 0,
#    'TEXT_chars': 528,
#    'FORM_chars': 591,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 528.0,
#    'FORM_avg_len': 118.2,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_213.xml',
#    'total_lines': 14,
#    'TEXT_lines': 0,
#    'FORM_lines': 14,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 635,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 45.357142857142854,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_214.xml',
#    'total_lines': 22,
#    'TEXT_lines': 0,
#    'FORM_lines': 22,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1199,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 54.5,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_215.xml',
#    'total_lines': 20,
#    'TEXT_lines': 0,
#    'FORM_lines': 4,
#    'TABLE_lines': 16,
#    'TEXT_chars': 0,
#    'FORM_chars': 251,
#    'TABLE_chars': 1276,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 62.75,
#    'TABLE_avg_len': 79.75},
#   {'filename': 'document_part_classification_216.xml',
#    'total_lines': 12,
#    'TEXT_lines': 0,
#    'FORM_lines': 12,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 348,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 29.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_217.xml',
#    'total_lines': 4,
#    'TEXT_lines': 1,
#    'FORM_lines': 3,
#    'TABLE_lines': 0,
#    'TEXT_chars': 371,
#    'FORM_chars': 242,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 371.0,
#    'FORM_avg_len': 80.66666666666667,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_218.xml',
#    'total_lines': 16,
#    'TEXT_lines': 0,
#    'FORM_lines': 16,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 766,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 47.875,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_219.xml',
#    'total_lines': 9,
#    'TEXT_lines': 2,
#    'FORM_lines': 7,
#    'TABLE_lines': 0,
#    'TEXT_chars': 716,
#    'FORM_chars': 417,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 358.0,
#    'FORM_avg_len': 59.57142857142857,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_22.xml',
#    'total_lines': 34,
#    'TEXT_lines': 0,
#    'FORM_lines': 34,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1768,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 52.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_220.xml',
#    'total_lines': 3,
#    'TEXT_lines': 0,
#    'FORM_lines': 3,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 248,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 82.66666666666667,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_221.xml',
#    'total_lines': 9,
#    'TEXT_lines': 0,
#    'FORM_lines': 9,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 513,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 57.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_222.xml',
#    'total_lines': 18,
#    'TEXT_lines': 1,
#    'FORM_lines': 17,
#    'TABLE_lines': 0,
#    'TEXT_chars': 343,
#    'FORM_chars': 917,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 343.0,
#    'FORM_avg_len': 53.94117647058823,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_223.xml',
#    'total_lines': 117,
#    'TEXT_lines': 3,
#    'FORM_lines': 25,
#    'TABLE_lines': 89,
#    'TEXT_chars': 1141,
#    'FORM_chars': 1295,
#    'TABLE_chars': 8520,
#    'TEXT_avg_len': 380.3333333333333,
#    'FORM_avg_len': 51.8,
#    'TABLE_avg_len': 95.73033707865169},
#   {'filename': 'document_part_classification_224.xml',
#    'total_lines': 28,
#    'TEXT_lines': 3,
#    'FORM_lines': 25,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1277,
#    'FORM_chars': 1978,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 425.6666666666667,
#    'FORM_avg_len': 79.12,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_225.xml',
#    'total_lines': 11,
#    'TEXT_lines': 1,
#    'FORM_lines': 10,
#    'TABLE_lines': 0,
#    'TEXT_chars': 532,
#    'FORM_chars': 253,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 532.0,
#    'FORM_avg_len': 25.3,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_226.xml',
#    'total_lines': 15,
#    'TEXT_lines': 0,
#    'FORM_lines': 15,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1036,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 69.06666666666666,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_227.xml',
#    'total_lines': 12,
#    'TEXT_lines': 2,
#    'FORM_lines': 10,
#    'TABLE_lines': 0,
#    'TEXT_chars': 854,
#    'FORM_chars': 676,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 427.0,
#    'FORM_avg_len': 67.6,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_228.xml',
#    'total_lines': 11,
#    'TEXT_lines': 2,
#    'FORM_lines': 9,
#    'TABLE_lines': 0,
#    'TEXT_chars': 779,
#    'FORM_chars': 448,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 389.5,
#    'FORM_avg_len': 49.77777777777778,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_229.xml',
#    'total_lines': 10,
#    'TEXT_lines': 4,
#    'FORM_lines': 6,
#    'TABLE_lines': 0,
#    'TEXT_chars': 2159,
#    'FORM_chars': 340,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 539.75,
#    'FORM_avg_len': 56.666666666666664,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_23.xml',
#    'total_lines': 16,
#    'TEXT_lines': 2,
#    'FORM_lines': 14,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1237,
#    'FORM_chars': 300,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 618.5,
#    'FORM_avg_len': 21.428571428571427,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_230.xml',
#    'total_lines': 16,
#    'TEXT_lines': 0,
#    'FORM_lines': 16,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 705,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 44.0625,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_231.xml',
#    'total_lines': 30,
#    'TEXT_lines': 2,
#    'FORM_lines': 28,
#    'TABLE_lines': 0,
#    'TEXT_chars': 802,
#    'FORM_chars': 1232,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 401.0,
#    'FORM_avg_len': 44.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_232.xml',
#    'total_lines': 25,
#    'TEXT_lines': 1,
#    'FORM_lines': 24,
#    'TABLE_lines': 0,
#    'TEXT_chars': 364,
#    'FORM_chars': 1033,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 364.0,
#    'FORM_avg_len': 43.041666666666664,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_233.xml',
#    'total_lines': 26,
#    'TEXT_lines': 0,
#    'FORM_lines': 26,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 2141,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 82.34615384615384,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_234.xml',
#    'total_lines': 21,
#    'TEXT_lines': 1,
#    'FORM_lines': 20,
#    'TABLE_lines': 0,
#    'TEXT_chars': 289,
#    'FORM_chars': 812,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 289.0,
#    'FORM_avg_len': 40.6,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_235.xml',
#    'total_lines': 7,
#    'TEXT_lines': 1,
#    'FORM_lines': 6,
#    'TABLE_lines': 0,
#    'TEXT_chars': 325,
#    'FORM_chars': 263,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 325.0,
#    'FORM_avg_len': 43.833333333333336,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_236.xml',
#    'total_lines': 16,
#    'TEXT_lines': 2,
#    'FORM_lines': 14,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1079,
#    'FORM_chars': 490,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 539.5,
#    'FORM_avg_len': 35.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_237.xml',
#    'total_lines': 39,
#    'TEXT_lines': 0,
#    'FORM_lines': 39,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 2868,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 73.53846153846153,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_238.xml',
#    'total_lines': 10,
#    'TEXT_lines': 0,
#    'FORM_lines': 10,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 525,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 52.5,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_239.xml',
#    'total_lines': 9,
#    'TEXT_lines': 2,
#    'FORM_lines': 7,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1027,
#    'FORM_chars': 402,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 513.5,
#    'FORM_avg_len': 57.42857142857143,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_24.xml',
#    'total_lines': 17,
#    'TEXT_lines': 1,
#    'FORM_lines': 16,
#    'TABLE_lines': 0,
#    'TEXT_chars': 362,
#    'FORM_chars': 962,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 362.0,
#    'FORM_avg_len': 60.125,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_240.xml',
#    'total_lines': 17,
#    'TEXT_lines': 1,
#    'FORM_lines': 16,
#    'TABLE_lines': 0,
#    'TEXT_chars': 337,
#    'FORM_chars': 1472,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 337.0,
#    'FORM_avg_len': 92.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_241.xml',
#    'total_lines': 16,
#    'TEXT_lines': 2,
#    'FORM_lines': 14,
#    'TABLE_lines': 0,
#    'TEXT_chars': 759,
#    'FORM_chars': 1218,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 379.5,
#    'FORM_avg_len': 87.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_242.xml',
#    'total_lines': 21,
#    'TEXT_lines': 0,
#    'FORM_lines': 21,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1282,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 61.04761904761905,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_243.xml',
#    'total_lines': 32,
#    'TEXT_lines': 1,
#    'FORM_lines': 31,
#    'TABLE_lines': 0,
#    'TEXT_chars': 734,
#    'FORM_chars': 2717,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 734.0,
#    'FORM_avg_len': 87.64516129032258,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_244.xml',
#    'total_lines': 21,
#    'TEXT_lines': 1,
#    'FORM_lines': 20,
#    'TABLE_lines': 0,
#    'TEXT_chars': 990,
#    'FORM_chars': 1034,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 990.0,
#    'FORM_avg_len': 51.7,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_245.xml',
#    'total_lines': 14,
#    'TEXT_lines': 2,
#    'FORM_lines': 12,
#    'TABLE_lines': 0,
#    'TEXT_chars': 869,
#    'FORM_chars': 954,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 434.5,
#    'FORM_avg_len': 79.5,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_246.xml',
#    'total_lines': 11,
#    'TEXT_lines': 0,
#    'FORM_lines': 11,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 261,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 23.727272727272727,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_247.xml',
#    'total_lines': 15,
#    'TEXT_lines': 0,
#    'FORM_lines': 15,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1243,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 82.86666666666666,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_248.xml',
#    'total_lines': 39,
#    'TEXT_lines': 0,
#    'FORM_lines': 39,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 2320,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 59.48717948717949,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_249.xml',
#    'total_lines': 28,
#    'TEXT_lines': 0,
#    'FORM_lines': 28,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 2061,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 73.60714285714286,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_25.xml',
#    'total_lines': 17,
#    'TEXT_lines': 1,
#    'FORM_lines': 16,
#    'TABLE_lines': 0,
#    'TEXT_chars': 356,
#    'FORM_chars': 772,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 356.0,
# ...
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 23.5,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_64.xml',
#    'total_lines': 20,
#    'TEXT_lines': 1,
#    'FORM_lines': 19,
#    'TABLE_lines': 0,
#    'TEXT_chars': 374,
#    'FORM_chars': 1812,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 374.0,
#    'FORM_avg_len': 95.36842105263158,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_640.xml',
#    'total_lines': 6,
#    'TEXT_lines': 0,
#    'FORM_lines': 6,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 289,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 48.166666666666664,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_641.xml',
#    'total_lines': 3,
#    'TEXT_lines': 1,
#    'FORM_lines': 2,
#    'TABLE_lines': 0,
#    'TEXT_chars': 365,
#    'FORM_chars': 82,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 365.0,
#    'FORM_avg_len': 41.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_642.xml',
#    'total_lines': 7,
#    'TEXT_lines': 0,
#    'FORM_lines': 7,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 458,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 65.42857142857143,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_643.xml',
#    'total_lines': 32,
#    'TEXT_lines': 8,
#    'FORM_lines': 24,
#    'TABLE_lines': 0,
#    'TEXT_chars': 3676,
#    'FORM_chars': 1506,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 459.5,
#    'FORM_avg_len': 62.75,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_644.xml',
#    'total_lines': 16,
#    'TEXT_lines': 4,
#    'FORM_lines': 3,
#    'TABLE_lines': 9,
#    'TEXT_chars': 2249,
#    'FORM_chars': 195,
#    'TABLE_chars': 303,
#    'TEXT_avg_len': 562.25,
#    'FORM_avg_len': 65.0,
#    'TABLE_avg_len': 33.666666666666664},
#   {'filename': 'document_part_classification_645.xml',
#    'total_lines': 11,
#    'TEXT_lines': 0,
#    'FORM_lines': 11,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 672,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 61.09090909090909,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_646.xml',
#    'total_lines': 19,
#    'TEXT_lines': 3,
#    'FORM_lines': 16,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1263,
#    'FORM_chars': 1398,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 421.0,
#    'FORM_avg_len': 87.375,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_647.xml',
#    'total_lines': 19,
#    'TEXT_lines': 0,
#    'FORM_lines': 19,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1853,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 97.52631578947368,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_648.xml',
#    'total_lines': 13,
#    'TEXT_lines': 0,
#    'FORM_lines': 13,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 434,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 33.38461538461539,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_649.xml',
#    'total_lines': 16,
#    'TEXT_lines': 1,
#    'FORM_lines': 15,
#    'TABLE_lines': 0,
#    'TEXT_chars': 581,
#    'FORM_chars': 765,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 581.0,
#    'FORM_avg_len': 51.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_65.xml',
#    'total_lines': 10,
#    'TEXT_lines': 3,
#    'FORM_lines': 7,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1323,
#    'FORM_chars': 485,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 441.0,
#    'FORM_avg_len': 69.28571428571429,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_650.xml',
#    'total_lines': 33,
#    'TEXT_lines': 3,
#    'FORM_lines': 30,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1291,
#    'FORM_chars': 2355,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 430.3333333333333,
#    'FORM_avg_len': 78.5,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_651.xml',
#    'total_lines': 16,
#    'TEXT_lines': 2,
#    'FORM_lines': 14,
#    'TABLE_lines': 0,
#    'TEXT_chars': 569,
#    'FORM_chars': 804,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 284.5,
#    'FORM_avg_len': 57.42857142857143,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_652.xml',
#    'total_lines': 27,
#    'TEXT_lines': 0,
#    'FORM_lines': 27,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1446,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 53.55555555555556,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_653.xml',
#    'total_lines': 4,
#    'TEXT_lines': 2,
#    'FORM_lines': 2,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1232,
#    'FORM_chars': 216,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 616.0,
#    'FORM_avg_len': 108.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_654.xml',
#    'total_lines': 23,
#    'TEXT_lines': 0,
#    'FORM_lines': 23,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 2188,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 95.1304347826087,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_655.xml',
#    'total_lines': 39,
#    'TEXT_lines': 3,
#    'FORM_lines': 36,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1753,
#    'FORM_chars': 3171,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 584.3333333333334,
#    'FORM_avg_len': 88.08333333333333,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_656.xml',
#    'total_lines': 7,
#    'TEXT_lines': 0,
#    'FORM_lines': 7,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 459,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 65.57142857142857,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_66.xml',
#    'total_lines': 15,
#    'TEXT_lines': 0,
#    'FORM_lines': 15,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1104,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 73.6,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_67.xml',
#    'total_lines': 28,
#    'TEXT_lines': 0,
#    'FORM_lines': 0,
#    'TABLE_lines': 28,
#    'TEXT_chars': 0,
#    'FORM_chars': 0,
#    'TABLE_chars': 2198,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 0,
#    'TABLE_avg_len': 78.5},
#   {'filename': 'document_part_classification_68.xml',
#    'total_lines': 10,
#    'TEXT_lines': 0,
#    'FORM_lines': 10,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 533,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 53.3,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_69.xml',
#    'total_lines': 6,
#    'TEXT_lines': 0,
#    'FORM_lines': 6,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 180,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 30.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_7.xml',
#    'total_lines': 37,
#    'TEXT_lines': 1,
#    'FORM_lines': 36,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1601,
#    'FORM_chars': 5346,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 1601.0,
#    'FORM_avg_len': 148.5,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_70.xml',
#    'total_lines': 15,
#    'TEXT_lines': 4,
#    'FORM_lines': 11,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1651,
#    'FORM_chars': 363,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 412.75,
#    'FORM_avg_len': 33.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_71.xml',
#    'total_lines': 20,
#    'TEXT_lines': 0,
#    'FORM_lines': 20,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1224,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 61.2,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_72.xml',
#    'total_lines': 15,
#    'TEXT_lines': 3,
#    'FORM_lines': 12,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1666,
#    'FORM_chars': 778,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 555.3333333333334,
#    'FORM_avg_len': 64.83333333333333,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_73.xml',
#    'total_lines': 6,
#    'TEXT_lines': 2,
#    'FORM_lines': 4,
#    'TABLE_lines': 0,
#    'TEXT_chars': 597,
#    'FORM_chars': 255,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 298.5,
#    'FORM_avg_len': 63.75,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_74.xml',
#    'total_lines': 21,
#    'TEXT_lines': 0,
#    'FORM_lines': 21,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 994,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 47.333333333333336,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_75.xml',
#    'total_lines': 17,
#    'TEXT_lines': 1,
#    'FORM_lines': 16,
#    'TABLE_lines': 0,
#    'TEXT_chars': 627,
#    'FORM_chars': 1242,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 627.0,
#    'FORM_avg_len': 77.625,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_76.xml',
#    'total_lines': 30,
#    'TEXT_lines': 0,
#    'FORM_lines': 30,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1396,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 46.53333333333333,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_77.xml',
#    'total_lines': 12,
#    'TEXT_lines': 0,
#    'FORM_lines': 12,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 580,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 48.333333333333336,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_78.xml',
#    'total_lines': 41,
#    'TEXT_lines': 0,
#    'FORM_lines': 41,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 3071,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 74.90243902439025,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_79.xml',
#    'total_lines': 8,
#    'TEXT_lines': 2,
#    'FORM_lines': 6,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1212,
#    'FORM_chars': 534,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 606.0,
#    'FORM_avg_len': 89.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_8.xml',
#    'total_lines': 8,
#    'TEXT_lines': 1,
#    'FORM_lines': 7,
#    'TABLE_lines': 0,
#    'TEXT_chars': 262,
#    'FORM_chars': 325,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 262.0,
#    'FORM_avg_len': 46.42857142857143,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_80.xml',
#    'total_lines': 7,
#    'TEXT_lines': 1,
#    'FORM_lines': 6,
#    'TABLE_lines': 0,
#    'TEXT_chars': 270,
#    'FORM_chars': 212,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 270.0,
#    'FORM_avg_len': 35.333333333333336,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_81.xml',
#    'total_lines': 15,
#    'TEXT_lines': 3,
#    'FORM_lines': 12,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1168,
#    'FORM_chars': 744,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 389.3333333333333,
#    'FORM_avg_len': 62.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_82.xml',
#    'total_lines': 32,
#    'TEXT_lines': 0,
#    'FORM_lines': 0,
#    'TABLE_lines': 32,
#    'TEXT_chars': 0,
#    'FORM_chars': 0,
#    'TABLE_chars': 2891,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 0,
#    'TABLE_avg_len': 90.34375},
#   {'filename': 'document_part_classification_83.xml',
#    'total_lines': 6,
#    'TEXT_lines': 2,
#    'FORM_lines': 4,
#    'TABLE_lines': 0,
#    'TEXT_chars': 631,
#    'FORM_chars': 125,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 315.5,
#    'FORM_avg_len': 31.25,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_84.xml',
#    'total_lines': 28,
#    'TEXT_lines': 0,
#    'FORM_lines': 28,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1753,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 62.607142857142854,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_85.xml',
#    'total_lines': 6,
#    'TEXT_lines': 1,
#    'FORM_lines': 5,
#    'TABLE_lines': 0,
#    'TEXT_chars': 495,
#    'FORM_chars': 265,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 495.0,
#    'FORM_avg_len': 53.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_86.xml',
#    'total_lines': 117,
#    'TEXT_lines': 3,
#    'FORM_lines': 25,
#    'TABLE_lines': 89,
#    'TEXT_chars': 1141,
#    'FORM_chars': 1295,
#    'TABLE_chars': 8520,
#    'TEXT_avg_len': 380.3333333333333,
#    'FORM_avg_len': 51.8,
#    'TABLE_avg_len': 95.73033707865169},
#   {'filename': 'document_part_classification_87.xml',
#    'total_lines': 26,
#    'TEXT_lines': 5,
#    'FORM_lines': 21,
#    'TABLE_lines': 0,
#    'TEXT_chars': 2906,
#    'FORM_chars': 1492,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 581.2,
#    'FORM_avg_len': 71.04761904761905,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_88.xml',
#    'total_lines': 19,
#    'TEXT_lines': 3,
#    'FORM_lines': 16,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1264,
#    'FORM_chars': 1301,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 421.3333333333333,
#    'FORM_avg_len': 81.3125,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_89.xml',
#    'total_lines': 14,
#    'TEXT_lines': 1,
#    'FORM_lines': 13,
#    'TABLE_lines': 0,
#    'TEXT_chars': 289,
#    'FORM_chars': 921,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 289.0,
#    'FORM_avg_len': 70.84615384615384,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_9.xml',
#    'total_lines': 30,
#    'TEXT_lines': 0,
#    'FORM_lines': 30,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 2481,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 82.7,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_90.xml',
#    'total_lines': 6,
#    'TEXT_lines': 0,
#    'FORM_lines': 6,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 414,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 69.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_91.xml',
#    'total_lines': 14,
#    'TEXT_lines': 0,
#    'FORM_lines': 14,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 639,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 45.642857142857146,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_92.xml',
#    'total_lines': 3,
#    'TEXT_lines': 0,
#    'FORM_lines': 3,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 111,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 37.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_93.xml',
#    'total_lines': 23,
#    'TEXT_lines': 2,
#    'FORM_lines': 21,
#    'TABLE_lines': 0,
#    'TEXT_chars': 1178,
#    'FORM_chars': 1447,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 589.0,
#    'FORM_avg_len': 68.9047619047619,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_94.xml',
#    'total_lines': 21,
#    'TEXT_lines': 0,
#    'FORM_lines': 21,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1512,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 72.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_95.xml',
#    'total_lines': 3,
#    'TEXT_lines': 1,
#    'FORM_lines': 2,
#    'TABLE_lines': 0,
#    'TEXT_chars': 499,
#    'FORM_chars': 124,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 499.0,
#    'FORM_avg_len': 62.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_96.xml',
#    'total_lines': 8,
#    'TEXT_lines': 1,
#    'FORM_lines': 7,
#    'TABLE_lines': 0,
#    'TEXT_chars': 272,
#    'FORM_chars': 448,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 272.0,
#    'FORM_avg_len': 64.0,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_97.xml',
#    'total_lines': 18,
#    'TEXT_lines': 1,
#    'FORM_lines': 17,
#    'TABLE_lines': 0,
#    'TEXT_chars': 301,
#    'FORM_chars': 605,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 301.0,
#    'FORM_avg_len': 35.588235294117645,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_98.xml',
#    'total_lines': 11,
#    'TEXT_lines': 0,
#    'FORM_lines': 11,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 502,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 45.63636363636363,
#    'TABLE_avg_len': 0},
#   {'filename': 'document_part_classification_99.xml',
#    'total_lines': 50,
#    'TEXT_lines': 0,
#    'FORM_lines': 50,
#    'TABLE_lines': 0,
#    'TEXT_chars': 0,
#    'FORM_chars': 1190,
#    'TABLE_chars': 0,
#    'TEXT_avg_len': 0,
#    'FORM_avg_len': 23.8,
#    'TABLE_avg_len': 0}]}
