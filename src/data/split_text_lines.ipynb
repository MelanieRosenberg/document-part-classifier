# %%
# Import necessary libraries
import os
import re
import logging
import json
from typing import List, Dict, Tuple

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

def split_text_by_length(text: str, target_length: int) -> List[str]:
    """
    Split text into segments of approximately target_length characters.
    Try to split on word boundaries.
    """
    words = text.split()
    segments = []
    current_segment = ""
    
    for word in words:
        # If adding this word would exceed target length and we already have content,
        # finish the current segment
        if current_segment and len(current_segment) + len(word) + 1 > target_length:
            segments.append(current_segment.strip())
            current_segment = ""
        
        # Add word to current segment
        current_segment += " " + word if current_segment else word
    
    # Add any remaining text
    if current_segment:
        segments.append(current_segment.strip())
    
    return segments

def split_text_on_sentences(text: str, target_length: int) -> List[str]:
    """
    Split text on sentence boundaries, trying to keep segments close to target_length.
    """
    # Simple sentence boundary detection (period, question mark, exclamation mark followed by space)
    sentence_end_pattern = r'[.!?](?=\s|$)'
    
    # Split into sentences
    sentences = re.split(sentence_end_pattern, text)
    sentences = [s + '.' if not s.endswith(('.', '!', '?')) else s for s in sentences if s.strip()]
    
    segments = []
    current_segment = ""
    
    for sentence in sentences:
        # If adding this sentence would exceed target length and we already have content,
        # finish the current segment
        if current_segment and len(current_segment) + len(sentence) > target_length:
            segments.append(current_segment.strip())
            current_segment = ""
        
        # If the sentence itself is longer than target_length, split it further
        if len(sentence) > target_length:
            if current_segment:
                segments.append(current_segment.strip())
                current_segment = ""
            
            # Split long sentence by length
            sentence_segments = split_text_by_length(sentence, target_length)
            segments.extend(sentence_segments)
        else:
            current_segment += " " + sentence if current_segment else sentence
    
    # Add any remaining text
    if current_segment:
        segments.append(current_segment.strip())
    
    return segments

def split_long_text_lines(
    input_dir: str,
    output_dir: str,
    target_length: int = 100,
    split_on_sentence: bool = True
) -> Dict:
    """
    Split long TEXT lines into shorter segments to balance the dataset.
    
    Args:
        input_dir: Directory containing *_lines.txt and *_labels.txt files
        output_dir: Directory to save processed files
        target_length: Target character length for TEXT lines
        split_on_sentence: Whether to try to split on sentence boundaries
        
    Returns:
        Dict containing statistics about the processing
    """
    os.makedirs(output_dir, exist_ok=True)
    
    stats = {
        'files_processed': 0,
        'original_lines': {'TEXT': 0, 'FORM': 0, 'TABLE': 0},
        'processed_lines': {'TEXT': 0, 'FORM': 0, 'TABLE': 0},
        'split_lines': 0,
        'original_char_counts': {'TEXT': 0, 'FORM': 0, 'TABLE': 0},
        'processed_char_counts': {'TEXT': 0, 'FORM': 0, 'TABLE': 0}
    }

    # Process each file pair in the directory
    for filename in os.listdir(input_dir):
        if not filename.endswith('_lines.txt'):
            continue
            
        lines_file = os.path.join(input_dir, filename)
        labels_file = os.path.join(input_dir, filename.replace('_lines.txt', '_labels.txt'))
        
        if not os.path.exists(labels_file):
            logger.warning(f"Labels file not found for {lines_file}, skipping")
            continue
        
        # Read files
        with open(lines_file, 'r', encoding='utf-8') as f:
            lines = [line.strip() for line in f.readlines()]
        
        with open(labels_file, 'r', encoding='utf-8') as f:
            labels = [label.strip() for label in f.readlines()]
        
        # Process lines and labels
        new_lines = []
        new_labels = []
        
        for i, (line, label) in enumerate(zip(lines, labels)):
            # Count original stats
            stats['original_lines'][label] = stats['original_lines'].get(label, 0) + 1
            stats['original_char_counts'][label] = stats['original_char_counts'].get(label, 0) + len(line)
            
            # Only split TEXT lines that are longer than target_length
            if label == 'TEXT' and len(line) > target_length:
                # Try to split on sentence boundaries if requested
                if split_on_sentence:
                    segments = split_text_on_sentences(line, target_length)
                else:
                    segments = split_text_by_length(line, target_length)
                
                new_lines.extend(segments)
                new_labels.extend(['TEXT'] * len(segments))
                
                stats['split_lines'] += 1
                stats['processed_lines']['TEXT'] += len(segments)
                stats['processed_char_counts']['TEXT'] += sum(len(segment) for segment in segments)
            else:
                # Keep non-TEXT lines or short TEXT lines as is
                new_lines.append(line)
                new_labels.append(label)
                stats['processed_lines'][label] = stats['processed_lines'].get(label, 0) + 1
                stats['processed_char_counts'][label] = stats['processed_char_counts'].get(label, 0) + len(line)
        
        # Write processed files
        output_lines_file = os.path.join(output_dir, filename)
        output_labels_file = os.path.join(output_dir, filename.replace('_lines.txt', '_labels.txt'))
        
        with open(output_lines_file, 'w', encoding='utf-8') as f:
            for line in new_lines:
                f.write(f"{line}\n")
        
        with open(output_labels_file, 'w', encoding='utf-8') as f:
            for label in new_labels:
                f.write(f"{label}\n")
        
        stats['files_processed'] += 1
        logger.info(f"Processed {filename}: {len(lines)} original lines -> {len(new_lines)} processed lines")
    
    # Save statistics
    stats_file = os.path.join(output_dir, "line_splitting_stats.json")
    with open(stats_file, 'w', encoding='utf-8') as f:
        json.dump(stats, f, indent=2)
    
    # Log summary statistics
    logger.info("\nText line splitting complete:")
    logger.info(f"Files processed: {stats['files_processed']}")
    logger.info(f"TEXT lines: {stats['original_lines']['TEXT']} original -> {stats['processed_lines']['TEXT']} processed")
    logger.info(f"FORM lines: {stats['original_lines']['FORM']} original -> {stats['processed_lines']['FORM']} processed")
    logger.info(f"TABLE lines: {stats['original_lines']['TABLE']} original -> {stats['processed_lines']['TABLE']} processed")
    
    # Calculate and log average lengths
    for label in ['TEXT', 'FORM', 'TABLE']:
        orig_avg_len = stats['original_char_counts'][label] / max(1, stats['original_lines'][label])
        proc_avg_len = stats['processed_char_counts'][label] / max(1, stats['processed_lines'][label])
        logger.info(f"{label} average length: {orig_avg_len:.1f} chars -> {proc_avg_len:.1f} chars")
    
    return stats

# Now use the function in your notebook
input_dir = "problem2_output"  # Your directory with lines and labels files
output_dir = "balanced_output"  # Where to save the processed files
target_length = 100  # Target character length for TEXT lines
split_on_sentence = True  # Try to split on sentence boundaries

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Run the splitting function
stats = split_long_text_lines(
    input_dir=input_dir,
    output_dir=output_dir,
    target_length=target_length,
    split_on_sentence=split_on_sentence
)

# Display results
print("\nOriginal dataset:")
print(f"TEXT: {stats['original_lines']['TEXT']} lines ({stats['original_lines']['TEXT']/sum(stats['original_lines'].values())*100:.1f}%)")
print(f"FORM: {stats['original_lines']['FORM']} lines ({stats['original_lines']['FORM']/sum(stats['original_lines'].values())*100:.1f}%)")
print(f"TABLE: {stats['original_lines']['TABLE']} lines ({stats['original_lines']['TABLE']/sum(stats['original_lines'].values())*100:.1f}%)")

print("\nProcessed dataset:")
print(f"TEXT: {stats['processed_lines']['TEXT']} lines ({stats['processed_lines']['TEXT']/sum(stats['processed_lines'].values())*100:.1f}%)")
print(f"FORM: {stats['processed_lines']['FORM']} lines ({stats['processed_lines']['FORM']/sum(stats['processed_lines'].values())*100:.1f}%)")
print(f"TABLE: {stats['processed_lines']['TABLE']} lines ({stats['processed_lines']['TABLE']/sum(stats['processed_lines'].values())*100:.1f}%)")
# Out:
# 2025-03-22 15:53:20,658 - INFO - Processed document_part_classification_345_lines.txt: 9 original lines -> 65 processed lines
# 2025-03-22 15:53:20,659 - INFO - Processed document_part_classification_459_lines.txt: 12 original lines -> 36 processed lines
# 2025-03-22 15:53:20,660 - INFO - Processed document_part_classification_173_lines.txt: 9 original lines -> 9 processed lines
# 2025-03-22 15:53:20,661 - INFO - Processed document_part_classification_490_lines.txt: 52 original lines -> 52 processed lines
# 2025-03-22 15:53:20,662 - INFO - Processed document_part_classification_203_lines.txt: 13 original lines -> 44 processed lines
# 2025-03-22 15:53:20,663 - INFO - Processed document_part_classification_279_lines.txt: 27 original lines -> 27 processed lines
# 2025-03-22 15:53:20,663 - INFO - Processed document_part_classification_565_lines.txt: 14 original lines -> 74 processed lines
# 2025-03-22 15:53:20,664 - INFO - Processed document_part_classification_615_lines.txt: 5 original lines -> 5 processed lines
# 2025-03-22 15:53:20,665 - INFO - Processed document_part_classification_423_lines.txt: 46 original lines -> 57 processed lines
# 2025-03-22 15:53:20,666 - INFO - Processed document_part_classification_109_lines.txt: 16 original lines -> 16 processed lines
# 2025-03-22 15:53:20,666 - INFO - Processed document_part_classification_437_lines.txt: 46 original lines -> 63 processed lines
# 2025-03-22 15:53:20,667 - INFO - Processed document_part_classification_601_lines.txt: 19 original lines -> 29 processed lines
# 2025-03-22 15:53:20,667 - INFO - Processed document_part_classification_571_lines.txt: 4 original lines -> 11 processed lines
# 2025-03-22 15:53:20,668 - INFO - Processed document_part_classification_14_lines.txt: 12 original lines -> 21 processed lines
# 2025-03-22 15:53:20,669 - INFO - Processed document_part_classification_217_lines.txt: 4 original lines -> 8 processed lines
# 2025-03-22 15:53:20,670 - INFO - Processed document_part_classification_484_lines.txt: 100 original lines -> 100 processed lines
# 2025-03-22 15:53:20,670 - INFO - Processed document_part_classification_167_lines.txt: 33 original lines -> 33 processed lines
# 2025-03-22 15:53:20,671 - INFO - Processed document_part_classification_398_lines.txt: 38 original lines -> 44 processed lines
# 2025-03-22 15:53:20,672 - INFO - Processed document_part_classification_351_lines.txt: 46 original lines -> 46 processed lines
# 2025-03-22 15:53:20,672 - INFO - Processed document_part_classification_620_lines.txt: 28 original lines -> 28 processed lines
# 2025-03-22 15:53:20,673 - INFO - Processed document_part_classification_416_lines.txt: 15 original lines -> 33 processed lines
# 2025-03-22 15:53:20,674 - INFO - Processed document_part_classification_285_lines.txt: 17 original lines -> 27 processed lines
# 2025-03-22 15:53:20,675 - INFO - Processed document_part_classification_599_lines.txt: 23 original lines -> 39 processed lines
# 2025-03-22 15:53:20,675 - INFO - Processed document_part_classification_550_lines.txt: 13 original lines -> 35 processed lines
# 2025-03-22 15:53:20,676 - INFO - Processed document_part_classification_35_lines.txt: 23 original lines -> 23 processed lines
# 2025-03-22 15:53:20,677 - INFO - Processed document_part_classification_236_lines.txt: 16 original lines -> 29 processed lines
# 2025-03-22 15:53:20,677 - INFO - Processed document_part_classification_370_lines.txt: 6 original lines -> 6 processed lines
# 2025-03-22 15:53:20,678 - INFO - Processed document_part_classification_146_lines.txt: 15 original lines -> 15 processed lines
# 2025-03-22 15:53:20,679 - INFO - Processed document_part_classification_86_lines.txt: 117 original lines -> 131 processed lines
# 2025-03-22 15:53:20,679 - INFO - Processed document_part_classification_92_lines.txt: 3 original lines -> 3 processed lines
# 2025-03-22 15:53:20,680 - INFO - Processed document_part_classification_152_lines.txt: 16 original lines -> 16 processed lines
# 2025-03-22 15:53:20,681 - INFO - Processed document_part_classification_478_lines.txt: 27 original lines -> 61 processed lines
# 2025-03-22 15:53:20,681 - INFO - Processed document_part_classification_364_lines.txt: 14 original lines -> 69 processed lines
# 2025-03-22 15:53:20,682 - INFO - Processed document_part_classification_222_lines.txt: 18 original lines -> 21 processed lines
# 2025-03-22 15:53:20,683 - INFO - Processed document_part_classification_21_lines.txt: 9 original lines -> 20 processed lines
# 2025-03-22 15:53:20,683 - INFO - Processed document_part_classification_544_lines.txt: 6 original lines -> 6 processed lines
# 2025-03-22 15:53:20,684 - INFO - Processed document_part_classification_258_lines.txt: 11 original lines -> 11 processed lines
# 2025-03-22 15:53:20,684 - INFO - Processed document_part_classification_291_lines.txt: 3 original lines -> 3 processed lines
# 2025-03-22 15:53:20,685 - INFO - Processed document_part_classification_128_lines.txt: 32 original lines -> 32 processed lines
# 2025-03-22 15:53:20,685 - INFO - Processed document_part_classification_402_lines.txt: 4 original lines -> 4 processed lines
# 2025-03-22 15:53:20,686 - INFO - Processed document_part_classification_634_lines.txt: 4 original lines -> 4 processed lines
# 2025-03-22 15:53:20,687 - INFO - Processed document_part_classification_512_lines.txt: 29 original lines -> 34 processed lines
# 2025-03-22 15:53:20,687 - INFO - Processed document_part_classification_454_lines.txt: 46 original lines -> 46 processed lines
# 2025-03-22 15:53:20,688 - INFO - Processed document_part_classification_348_lines.txt: 35 original lines -> 35 processed lines
# 2025-03-22 15:53:20,689 - INFO - Processed document_part_classification_381_lines.txt: 14 original lines -> 14 processed lines
# 2025-03-22 15:53:20,690 - INFO - Processed document_part_classification_77_lines.txt: 12 original lines -> 12 processed lines
# 2025-03-22 15:53:20,690 - INFO - Processed document_part_classification_104_lines.txt: 21 original lines -> 21 processed lines
# 2025-03-22 15:53:20,691 - INFO - Processed document_part_classification_332_lines.txt: 4 original lines -> 4 processed lines
# 2025-03-22 15:53:20,692 - INFO - Processed document_part_classification_618_lines.txt: 14 original lines -> 16 processed lines
# 2025-03-22 15:53:20,692 - INFO - Processed document_part_classification_568_lines.txt: 27 original lines -> 32 processed lines
# 2025-03-22 15:53:20,693 - INFO - Processed document_part_classification_274_lines.txt: 22 original lines -> 30 processed lines
# 2025-03-22 15:53:20,694 - INFO - Processed document_part_classification_19_lines.txt: 18 original lines -> 38 processed lines
# 2025-03-22 15:53:20,695 - INFO - Processed document_part_classification_260_lines.txt: 8 original lines -> 12 processed lines
# 2025-03-22 15:53:20,695 - INFO - Processed document_part_classification_326_lines.txt: 13 original lines -> 54 processed lines
# 2025-03-22 15:53:20,696 - INFO - Processed document_part_classification_110_lines.txt: 29 original lines -> 58 processed lines
# 2025-03-22 15:53:20,697 - INFO - Processed document_part_classification_1_lines.txt: 26 original lines -> 33 processed lines
# 2025-03-22 15:53:20,698 - INFO - Processed document_part_classification_63_lines.txt: 14 original lines -> 19 processed lines
# 2025-03-22 15:53:20,698 - INFO - Processed document_part_classification_395_lines.txt: 15 original lines -> 71 processed lines
# 2025-03-22 15:53:20,699 - INFO - Processed document_part_classification_489_lines.txt: 50 original lines -> 50 processed lines
# 2025-03-22 15:53:20,700 - INFO - Processed document_part_classification_440_lines.txt: 14 original lines -> 68 processed lines
# 2025-03-22 15:53:20,700 - INFO - Processed document_part_classification_506_lines.txt: 8 original lines -> 37 processed lines
# 2025-03-22 15:53:20,701 - INFO - Processed document_part_classification_38_lines.txt: 7 original lines -> 7 processed lines
# 2025-03-22 15:53:20,701 - INFO - Processed document_part_classification_594_lines.txt: 4 original lines -> 26 processed lines
# 2025-03-22 15:53:20,702 - INFO - Processed document_part_classification_288_lines.txt: 11 original lines -> 15 processed lines
# 2025-03-22 15:53:20,703 - INFO - Processed document_part_classification_241_lines.txt: 16 original lines -> 25 processed lines
# 2025-03-22 15:53:20,703 - INFO - Processed document_part_classification_131_lines.txt: 6 original lines -> 6 processed lines
# 2025-03-22 15:53:20,704 - INFO - Processed document_part_classification_307_lines.txt: 15 original lines -> 38 processed lines
# 2025-03-22 15:53:20,708 - INFO - Processed document_part_classification_42_lines.txt: 34 original lines -> 34 processed lines
# 2025-03-22 15:53:20,711 - INFO - Processed document_part_classification_461_lines.txt: 7 original lines -> 46 processed lines
# 2025-03-22 15:53:20,712 - INFO - Processed document_part_classification_182_lines.txt: 23 original lines -> 25 processed lines
# 2025-03-22 15:53:20,713 - INFO - Processed document_part_classification_527_lines.txt: 28 original lines -> 47 processed lines
# 2025-03-22 15:53:20,714 - INFO - Processed document_part_classification_533_lines.txt: 15 original lines -> 42 processed lines
# 2025-03-22 15:53:20,715 - INFO - Processed document_part_classification_643_lines.txt: 32 original lines -> 67 processed lines
# 2025-03-22 15:53:20,716 - INFO - Processed document_part_classification_369_lines.txt: 15 original lines -> 15 processed lines
# 2025-03-22 15:53:20,716 - INFO - Processed document_part_classification_196_lines.txt: 14 original lines -> 14 processed lines
# 2025-03-22 15:53:20,717 - INFO - Processed document_part_classification_475_lines.txt: 24 original lines -> 56 processed lines
# 2025-03-22 15:53:20,717 - INFO - Processed document_part_classification_56_lines.txt: 3 original lines -> 3 processed lines
# 2025-03-22 15:53:20,718 - INFO - Processed document_part_classification_639_lines.txt: 16 original lines -> 16 processed lines
# 2025-03-22 15:53:20,719 - INFO - Processed document_part_classification_313_lines.txt: 19 original lines -> 19 processed lines
# 2025-03-22 15:53:20,719 - INFO - Processed document_part_classification_125_lines.txt: 31 original lines -> 31 processed lines
# 2025-03-22 15:53:20,720 - INFO - Processed document_part_classification_255_lines.txt: 15 original lines -> 15 processed lines
# 2025-03-22 15:53:20,721 - INFO - Processed document_part_classification_549_lines.txt: 16 original lines -> 38 processed lines
# 2025-03-22 15:53:20,721 - INFO - Processed document_part_classification_580_lines.txt: 2 original lines -> 2 processed lines
# 2025-03-22 15:53:20,722 - INFO - Processed document_part_classification_376_lines.txt: 22 original lines -> 22 processed lines
# 2025-03-22 15:53:20,723 - INFO - Processed document_part_classification_140_lines.txt: 13 original lines -> 19 processed lines
# 2025-03-22 15:53:20,723 - INFO - Processed document_part_classification_189_lines.txt: 11 original lines -> 11 processed lines
# 2025-03-22 15:53:20,724 - INFO - Processed document_part_classification_230_lines.txt: 16 original lines -> 16 processed lines
# 2025-03-22 15:53:20,724 - INFO - Processed document_part_classification_80_lines.txt: 7 original lines -> 10 processed lines
# 2025-03-22 15:53:20,725 - INFO - Processed document_part_classification_49_lines.txt: 14 original lines -> 14 processed lines
# 2025-03-22 15:53:20,726 - INFO - Processed document_part_classification_283_lines.txt: 4 original lines -> 14 processed lines
# 2025-03-22 15:53:20,726 - INFO - Processed document_part_classification_556_lines.txt: 13 original lines -> 25 processed lines
# 2025-03-22 15:53:20,727 - INFO - Processed document_part_classification_626_lines.txt: 19 original lines -> 25 processed lines
# 2025-03-22 15:53:20,728 - INFO - Processed document_part_classification_410_lines.txt: 31 original lines -> 68 processed lines
# 2025-03-22 15:53:20,728 - INFO - Processed document_part_classification_33_lines.txt: 23 original lines -> 29 processed lines
# 2025-03-22 15:53:20,729 - INFO - Processed document_part_classification_27_lines.txt: 6 original lines -> 6 processed lines
# 2025-03-22 15:53:20,730 - INFO - Processed document_part_classification_404_lines.txt: 7 original lines -> 14 processed lines
# 2025-03-22 15:53:20,731 - INFO - Processed document_part_classification_318_lines.txt: 28 original lines -> 74 processed lines
# 2025-03-22 15:53:20,731 - INFO - Processed document_part_classification_632_lines.txt: 26 original lines -> 33 processed lines
# 2025-03-22 15:53:20,732 - INFO - Processed document_part_classification_542_lines.txt: 29 original lines -> 29 processed lines
# 2025-03-22 15:53:20,732 - INFO - Processed document_part_classification_297_lines.txt: 28 original lines -> 28 processed lines
# 2025-03-22 15:53:20,733 - INFO - Processed document_part_classification_94_lines.txt: 21 original lines -> 21 processed lines
# 2025-03-22 15:53:20,734 - INFO - Processed document_part_classification_538_lines.txt: 50 original lines -> 50 processed lines
# 2025-03-22 15:53:20,734 - INFO - Processed document_part_classification_224_lines.txt: 28 original lines -> 44 processed lines
# 2025-03-22 15:53:20,735 - INFO - Processed document_part_classification_154_lines.txt: 24 original lines -> 24 processed lines
# 2025-03-22 15:53:20,735 - INFO - Processed document_part_classification_362_lines.txt: 29 original lines -> 50 processed lines
# 2025-03-22 15:53:20,736 - INFO - Processed document_part_classification_648_lines.txt: 13 original lines -> 13 processed lines
# 2025-03-22 15:53:20,736 - INFO - Processed document_part_classification_613_lines.txt: 10 original lines -> 10 processed lines
# 2025-03-22 15:53:20,737 - INFO - Processed document_part_classification_339_lines.txt: 53 original lines -> 63 processed lines
# 2025-03-22 15:53:20,738 - INFO - Processed document_part_classification_425_lines.txt: 56 original lines -> 56 processed lines
# 2025-03-22 15:53:20,739 - INFO - Processed document_part_classification_563_lines.txt: 15 original lines -> 64 processed lines
# 2025-03-22 15:53:20,740 - INFO - Processed document_part_classification_205_lines.txt: 8 original lines -> 8 processed lines
# 2025-03-22 15:53:20,741 - INFO - Processed document_part_classification_519_lines.txt: 21 original lines -> 21 processed lines
# 2025-03-22 15:53:20,741 - INFO - Processed document_part_classification_343_lines.txt: 27 original lines -> 81 processed lines
# 2025-03-22 15:53:20,742 - INFO - Processed document_part_classification_175_lines.txt: 8 original lines -> 8 processed lines
# 2025-03-22 15:53:20,742 - INFO - Processed document_part_classification_496_lines.txt: 8 original lines -> 20 processed lines
# 2025-03-22 15:53:20,743 - INFO - Processed document_part_classification_482_lines.txt: 5 original lines -> 10 processed lines
# 2025-03-22 15:53:20,744 - INFO - Processed document_part_classification_161_lines.txt: 5 original lines -> 5 processed lines
# 2025-03-22 15:53:20,744 - INFO - Processed document_part_classification_357_lines.txt: 21 original lines -> 42 processed lines
# 2025-03-22 15:53:20,745 - INFO - Processed document_part_classification_211_lines.txt: 14 original lines -> 14 processed lines
# 2025-03-22 15:53:20,745 - INFO - Processed document_part_classification_68_lines.txt: 10 original lines -> 10 processed lines
# 2025-03-22 15:53:20,746 - INFO - Processed document_part_classification_577_lines.txt: 4 original lines -> 11 processed lines
# 2025-03-22 15:53:20,746 - INFO - Processed document_part_classification_431_lines.txt: 20 original lines -> 20 processed lines
# 2025-03-22 15:53:20,747 - INFO - Processed document_part_classification_607_lines.txt: 21 original lines -> 24 processed lines
# 2025-03-22 15:53:20,748 - INFO - Processed document_part_classification_12_lines.txt: 22 original lines -> 74 processed lines
# 2025-03-22 15:53:20,748 - INFO - Processed document_part_classification_44_lines.txt: 12 original lines -> 23 processed lines
# 2025-03-22 15:53:20,749 - INFO - Processed document_part_classification_521_lines.txt: 37 original lines -> 37 processed lines
# 2025-03-22 15:53:20,750 - INFO - Processed document_part_classification_467_lines.txt: 16 original lines -> 48 processed lines
# 2025-03-22 15:53:20,750 - INFO - Processed document_part_classification_184_lines.txt: 7 original lines -> 7 processed lines
# 2025-03-22 15:53:20,751 - INFO - Processed document_part_classification_651_lines.txt: 16 original lines -> 22 processed lines
# 2025-03-22 15:53:20,752 - INFO - Processed document_part_classification_137_lines.txt: 16 original lines -> 19 processed lines
# 2025-03-22 15:53:20,752 - INFO - Processed document_part_classification_301_lines.txt: 17 original lines -> 39 processed lines
# 2025-03-22 15:53:20,753 - INFO - Processed document_part_classification_592_lines.txt: 16 original lines -> 28 processed lines
# 2025-03-22 15:53:20,754 - INFO - Processed document_part_classification_247_lines.txt: 15 original lines -> 15 processed lines
# 2025-03-22 15:53:20,754 - INFO - Processed document_part_classification_253_lines.txt: 7 original lines -> 10 processed lines
# 2025-03-22 15:53:20,755 - INFO - Processed document_part_classification_586_lines.txt: 19 original lines -> 19 processed lines
# 2025-03-22 15:53:20,755 - INFO - Processed document_part_classification_315_lines.txt: 12 original lines -> 27 processed lines
# 2025-03-22 15:53:20,756 - INFO - Processed document_part_classification_409_lines.txt: 5 original lines -> 55 processed lines
# 2025-03-22 15:53:20,759 - INFO - Processed document_part_classification_123_lines.txt: 11 original lines -> 32 processed lines
# 2025-03-22 15:53:20,761 - INFO - Processed document_part_classification_645_lines.txt: 11 original lines -> 11 processed lines
# 2025-03-22 15:53:20,763 - INFO - Processed document_part_classification_190_lines.txt: 13 original lines -> 13 processed lines
# 2025-03-22 15:53:20,763 - INFO - Processed document_part_classification_473_lines.txt: 33 original lines -> 33 processed lines
# 2025-03-22 15:53:20,764 - INFO - Processed document_part_classification_159_lines.txt: 10 original lines -> 16 processed lines
# 2025-03-22 15:53:20,765 - INFO - Processed document_part_classification_229_lines.txt: 10 original lines -> 33 processed lines
# 2025-03-22 15:53:20,766 - INFO - Processed document_part_classification_535_lines.txt: 33 original lines -> 38 processed lines
# 2025-03-22 15:53:20,767 - INFO - Processed document_part_classification_50_lines.txt: 14 original lines -> 14 processed lines
# 2025-03-22 15:53:20,768 - INFO - Processed document_part_classification_99_lines.txt: 50 original lines -> 50 processed lines
# 2025-03-22 15:53:20,769 - INFO - Processed document_part_classification_272_lines.txt: 9 original lines -> 9 processed lines
# 2025-03-22 15:53:20,770 - INFO - Processed document_part_classification_102_lines.txt: 12 original lines -> 12 processed lines
# 2025-03-22 15:53:20,771 - INFO - Processed document_part_classification_428_lines.txt: 16 original lines -> 64 processed lines
# 2025-03-22 15:53:20,771 - INFO - Processed document_part_classification_334_lines.txt: 21 original lines -> 77 processed lines
# 2025-03-22 15:53:20,772 - INFO - Processed document_part_classification_178_lines.txt: 21 original lines -> 21 processed lines
# 2025-03-22 15:53:20,773 - INFO - Processed document_part_classification_452_lines.txt: 21 original lines -> 24 processed lines
# 2025-03-22 15:53:20,773 - INFO - Processed document_part_classification_387_lines.txt: 28 original lines -> 28 processed lines
# 2025-03-22 15:53:20,774 - INFO - Processed document_part_classification_514_lines.txt: 34 original lines -> 49 processed lines
# 2025-03-22 15:53:20,775 - INFO - Processed document_part_classification_208_lines.txt: 10 original lines -> 14 processed lines
# 2025-03-22 15:53:20,775 - INFO - Processed document_part_classification_71_lines.txt: 20 original lines -> 20 processed lines
# 2025-03-22 15:53:20,776 - INFO - Processed document_part_classification_65_lines.txt: 10 original lines -> 25 processed lines
# 2025-03-22 15:53:20,776 - INFO - Processed document_part_classification_500_lines.txt: 27 original lines -> 27 processed lines
# 2025-03-22 15:53:20,777 - INFO - Processed document_part_classification_393_lines.txt: 51 original lines -> 51 processed lines
# 2025-03-22 15:53:20,778 - INFO - Processed document_part_classification_446_lines.txt: 42 original lines -> 104 processed lines
# 2025-03-22 15:53:20,778 - INFO - Processed document_part_classification_320_lines.txt: 59 original lines -> 67 processed lines
# 2025-03-22 15:53:20,779 - INFO - Processed document_part_classification_116_lines.txt: 53 original lines -> 53 processed lines
# 2025-03-22 15:53:20,780 - INFO - Processed document_part_classification_7_lines.txt: 37 original lines -> 60 processed lines
# 2025-03-22 15:53:20,780 - INFO - Processed document_part_classification_266_lines.txt: 9 original lines -> 9 processed lines
# 2025-03-22 15:53:20,781 - INFO - Processed document_part_classification_570_lines.txt: 5 original lines -> 8 processed lines
# 2025-03-22 15:53:20,782 - INFO - Processed document_part_classification_436_lines.txt: 21 original lines -> 61 processed lines
# 2025-03-22 15:53:20,782 - INFO - Processed document_part_classification_600_lines.txt: 7 original lines -> 22 processed lines
# 2025-03-22 15:53:20,783 - INFO - Processed document_part_classification_15_lines.txt: 3 original lines -> 11 processed lines
# 2025-03-22 15:53:20,783 - INFO - Processed document_part_classification_485_lines.txt: 14 original lines -> 30 processed lines
# 2025-03-22 15:53:20,784 - INFO - Processed document_part_classification_166_lines.txt: 9 original lines -> 25 processed lines
# 2025-03-22 15:53:20,785 - INFO - Processed document_part_classification_399_lines.txt: 25 original lines -> 65 processed lines
# 2025-03-22 15:53:20,785 - INFO - Processed document_part_classification_350_lines.txt: 21 original lines -> 24 processed lines
# 2025-03-22 15:53:20,786 - INFO - Processed document_part_classification_216_lines.txt: 12 original lines -> 12 processed lines
# 2025-03-22 15:53:20,787 - INFO - Processed document_part_classification_202_lines.txt: 9 original lines -> 35 processed lines
# 2025-03-22 15:53:20,787 - INFO - Processed document_part_classification_344_lines.txt: 23 original lines -> 39 processed lines
# 2025-03-22 15:53:20,788 - INFO - Processed document_part_classification_458_lines.txt: 22 original lines -> 26 processed lines
# 2025-03-22 15:53:20,789 - INFO - Processed document_part_classification_172_lines.txt: 8 original lines -> 12 processed lines
# 2025-03-22 15:53:20,789 - INFO - Processed document_part_classification_491_lines.txt: 18 original lines -> 38 processed lines
# 2025-03-22 15:53:20,790 - INFO - Processed document_part_classification_614_lines.txt: 5 original lines -> 8 processed lines
# 2025-03-22 15:53:20,790 - INFO - Processed document_part_classification_422_lines.txt: 40 original lines -> 40 processed lines
# 2025-03-22 15:53:20,791 - INFO - Processed document_part_classification_108_lines.txt: 13 original lines -> 13 processed lines
# 2025-03-22 15:53:20,791 - INFO - Processed document_part_classification_278_lines.txt: 9 original lines -> 21 processed lines
# 2025-03-22 15:53:20,792 - INFO - Processed document_part_classification_564_lines.txt: 48 original lines -> 65 processed lines
# 2025-03-22 15:53:20,793 - INFO - Processed document_part_classification_93_lines.txt: 23 original lines -> 35 processed lines
# 2025-03-22 15:53:20,794 - INFO - Processed document_part_classification_223_lines.txt: 117 original lines -> 131 processed lines
# 2025-03-22 15:53:20,794 - INFO - Processed document_part_classification_153_lines.txt: 13 original lines -> 19 processed lines
# 2025-03-22 15:53:20,795 - INFO - Processed document_part_classification_479_lines.txt: 12 original lines -> 33 processed lines
# 2025-03-22 15:53:20,795 - INFO - Processed document_part_classification_365_lines.txt: 29 original lines -> 91 processed lines
# 2025-03-22 15:53:20,796 - INFO - Processed document_part_classification_20_lines.txt: 5 original lines -> 13 processed lines
# 2025-03-22 15:53:20,797 - INFO - Processed document_part_classification_129_lines.txt: 8 original lines -> 10 processed lines
# 2025-03-22 15:53:20,797 - INFO - Processed document_part_classification_403_lines.txt: 16 original lines -> 49 processed lines
# 2025-03-22 15:53:20,798 - INFO - Processed document_part_classification_635_lines.txt: 25 original lines -> 62 processed lines
# 2025-03-22 15:53:20,799 - INFO - Processed document_part_classification_545_lines.txt: 29 original lines -> 29 processed lines
# 2025-03-22 15:53:20,799 - INFO - Processed document_part_classification_259_lines.txt: 42 original lines -> 42 processed lines
# 2025-03-22 15:53:20,800 - INFO - Processed document_part_classification_290_lines.txt: 29 original lines -> 29 processed lines
# 2025-03-22 15:53:20,800 - INFO - Processed document_part_classification_284_lines.txt: 12 original lines -> 21 processed lines
# 2025-03-22 15:53:20,801 - INFO - Processed document_part_classification_598_lines.txt: 12 original lines -> 64 processed lines
# 2025-03-22 15:53:20,802 - INFO - Processed document_part_classification_551_lines.txt: 45 original lines -> 45 processed lines
# 2025-03-22 15:53:20,802 - INFO - Processed document_part_classification_621_lines.txt: 24 original lines -> 24 processed lines
# 2025-03-22 15:53:20,803 - INFO - Processed document_part_classification_417_lines.txt: 25 original lines -> 39 processed lines
# 2025-03-22 15:53:20,804 - INFO - Processed document_part_classification_34_lines.txt: 12 original lines -> 12 processed lines
# 2025-03-22 15:53:20,804 - INFO - Processed document_part_classification_371_lines.txt: 3 original lines -> 6 processed lines
# 2025-03-22 15:53:20,804 - INFO - Processed document_part_classification_147_lines.txt: 23 original lines -> 23 processed lines
# 2025-03-22 15:53:20,805 - INFO - Processed document_part_classification_237_lines.txt: 39 original lines -> 39 processed lines
# 2025-03-22 15:53:20,806 - INFO - Processed document_part_classification_87_lines.txt: 26 original lines -> 56 processed lines
# 2025-03-22 15:53:20,807 - INFO - Processed document_part_classification_18_lines.txt: 8 original lines -> 8 processed lines
# 2025-03-22 15:53:20,807 - INFO - Processed document_part_classification_327_lines.txt: 32 original lines -> 32 processed lines
# 2025-03-22 15:53:20,808 - INFO - Processed document_part_classification_111_lines.txt: 12 original lines -> 26 processed lines
# 2025-03-22 15:53:20,808 - INFO - Processed document_part_classification_261_lines.txt: 7 original lines -> 23 processed lines
# 2025-03-22 15:53:20,809 - INFO - Processed document_part_classification_62_lines.txt: 35 original lines -> 35 processed lines
# 2025-03-22 15:53:20,809 - INFO - Processed document_part_classification_507_lines.txt: 47 original lines -> 47 processed lines
# 2025-03-22 15:53:20,810 - INFO - Processed document_part_classification_394_lines.txt: 5 original lines -> 26 processed lines
# 2025-03-22 15:53:20,811 - INFO - Processed document_part_classification_488_lines.txt: 102 original lines -> 102 processed lines
# 2025-03-22 15:53:20,811 - INFO - Processed document_part_classification_441_lines.txt: 18 original lines -> 38 processed lines
# 2025-03-22 15:53:20,812 - INFO - Processed document_part_classification_455_lines.txt: 7 original lines -> 15 processed lines
# 2025-03-22 15:53:20,812 - INFO - Processed document_part_classification_349_lines.txt: 26 original lines -> 26 processed lines
# 2025-03-22 15:53:20,813 - INFO - Processed document_part_classification_380_lines.txt: 30 original lines -> 61 processed lines
# 2025-03-22 15:53:20,818 - INFO - Processed document_part_classification_513_lines.txt: 30 original lines -> 91 processed lines
# 2025-03-22 15:53:20,819 - INFO - Processed document_part_classification_76_lines.txt: 30 original lines -> 30 processed lines
# 2025-03-22 15:53:20,821 - INFO - Processed document_part_classification_569_lines.txt: 13 original lines -> 28 processed lines
# 2025-03-22 15:53:20,821 - INFO - Processed document_part_classification_275_lines.txt: 6 original lines -> 21 processed lines
# 2025-03-22 15:53:20,822 - INFO - Processed document_part_classification_105_lines.txt: 21 original lines -> 48 processed lines
# 2025-03-22 15:53:20,823 - INFO - Processed document_part_classification_333_lines.txt: 16 original lines -> 72 processed lines
# 2025-03-22 15:53:20,823 - INFO - Processed document_part_classification_619_lines.txt: 19 original lines -> 24 processed lines
# 2025-03-22 15:53:20,824 - INFO - Processed document_part_classification_642_lines.txt: 7 original lines -> 7 processed lines
# 2025-03-22 15:53:20,825 - INFO - Processed document_part_classification_368_lines.txt: 29 original lines -> 29 processed lines
# 2025-03-22 15:53:20,825 - INFO - Processed document_part_classification_197_lines.txt: 11 original lines -> 18 processed lines
# 2025-03-22 15:53:20,826 - INFO - Processed document_part_classification_474_lines.txt: 20 original lines -> 68 processed lines
# 2025-03-22 15:53:20,827 - INFO - Processed document_part_classification_532_lines.txt: 22 original lines -> 22 processed lines
# 2025-03-22 15:53:20,827 - INFO - Processed document_part_classification_57_lines.txt: 52 original lines -> 77 processed lines
# 2025-03-22 15:53:20,828 - INFO - Processed document_part_classification_254_lines.txt: 4 original lines -> 4 processed lines
# 2025-03-22 15:53:20,828 - INFO - Processed document_part_classification_548_lines.txt: 27 original lines -> 27 processed lines
# 2025-03-22 15:53:20,829 - INFO - Processed document_part_classification_581_lines.txt: 13 original lines -> 30 processed lines
# 2025-03-22 15:53:20,830 - INFO - Processed document_part_classification_638_lines.txt: 12 original lines -> 19 processed lines
# 2025-03-22 15:53:20,830 - INFO - Processed document_part_classification_312_lines.txt: 18 original lines -> 29 processed lines
# 2025-03-22 15:53:20,831 - INFO - Processed document_part_classification_124_lines.txt: 15 original lines -> 44 processed lines
# 2025-03-22 15:53:20,831 - INFO - Processed document_part_classification_39_lines.txt: 9 original lines -> 11 processed lines
# 2025-03-22 15:53:20,832 - INFO - Processed document_part_classification_130_lines.txt: 6 original lines -> 10 processed lines
# 2025-03-22 15:53:20,833 - INFO - Processed document_part_classification_306_lines.txt: 35 original lines -> 57 processed lines
# 2025-03-22 15:53:20,833 - INFO - Processed document_part_classification_595_lines.txt: 8 original lines -> 29 processed lines
# 2025-03-22 15:53:20,834 - INFO - Processed document_part_classification_289_lines.txt: 25 original lines -> 25 processed lines
# 2025-03-22 15:53:20,834 - INFO - Processed document_part_classification_240_lines.txt: 17 original lines -> 20 processed lines
# 2025-03-22 15:53:20,835 - INFO - Processed document_part_classification_43_lines.txt: 7 original lines -> 7 processed lines
# 2025-03-22 15:53:20,836 - INFO - Processed document_part_classification_526_lines.txt: 8 original lines -> 81 processed lines
# 2025-03-22 15:53:20,837 - INFO - Processed document_part_classification_460_lines.txt: 13 original lines -> 47 processed lines
# 2025-03-22 15:53:20,838 - INFO - Processed document_part_classification_183_lines.txt: 14 original lines -> 14 processed lines
# 2025-03-22 15:53:20,839 - INFO - Processed document_part_classification_656_lines.txt: 7 original lines -> 7 processed lines
# 2025-03-22 15:53:20,839 - INFO - Processed document_part_classification_26_lines.txt: 20 original lines -> 31 processed lines
# 2025-03-22 15:53:20,840 - INFO - Processed document_part_classification_543_lines.txt: 29 original lines -> 29 processed lines
# 2025-03-22 15:53:20,841 - INFO - Processed document_part_classification_296_lines.txt: 2 original lines -> 2 processed lines
# 2025-03-22 15:53:20,841 - INFO - Processed document_part_classification_405_lines.txt: 32 original lines -> 32 processed lines
# 2025-03-22 15:53:20,842 - INFO - Processed document_part_classification_319_lines.txt: 6 original lines -> 6 processed lines
# 2025-03-22 15:53:20,843 - INFO - Processed document_part_classification_633_lines.txt: 14 original lines -> 14 processed lines
# 2025-03-22 15:53:20,844 - INFO - Processed document_part_classification_95_lines.txt: 3 original lines -> 9 processed lines
# 2025-03-22 15:53:20,844 - INFO - Processed document_part_classification_155_lines.txt: 11 original lines -> 36 processed lines
# 2025-03-22 15:53:20,845 - INFO - Processed document_part_classification_363_lines.txt: 42 original lines -> 59 processed lines
# 2025-03-22 15:53:20,845 - INFO - Processed document_part_classification_649_lines.txt: 16 original lines -> 22 processed lines
# 2025-03-22 15:53:20,846 - INFO - Processed document_part_classification_539_lines.txt: 22 original lines -> 22 processed lines
# 2025-03-22 15:53:20,847 - INFO - Processed document_part_classification_225_lines.txt: 11 original lines -> 18 processed lines
# 2025-03-22 15:53:20,848 - INFO - Processed document_part_classification_231_lines.txt: 30 original lines -> 40 processed lines
# 2025-03-22 15:53:20,848 - INFO - Processed document_part_classification_377_lines.txt: 28 original lines -> 28 processed lines
# 2025-03-22 15:53:20,849 - INFO - Processed document_part_classification_141_lines.txt: 11 original lines -> 31 processed lines
# 2025-03-22 15:53:20,850 - INFO - Processed document_part_classification_188_lines.txt: 26 original lines -> 26 processed lines
# 2025-03-22 15:53:20,850 - INFO - Processed document_part_classification_81_lines.txt: 15 original lines -> 25 processed lines
# 2025-03-22 15:53:20,851 - INFO - Processed document_part_classification_48_lines.txt: 18 original lines -> 31 processed lines
# 2025-03-22 15:53:20,851 - INFO - Processed document_part_classification_627_lines.txt: 3 original lines -> 3 processed lines
# 2025-03-22 15:53:20,852 - INFO - Processed document_part_classification_411_lines.txt: 47 original lines -> 68 processed lines
# 2025-03-22 15:53:20,852 - INFO - Processed document_part_classification_282_lines.txt: 17 original lines -> 17 processed lines
# 2025-03-22 15:53:20,854 - INFO - Processed document_part_classification_557_lines.txt: 22 original lines -> 39 processed lines
# 2025-03-22 15:53:20,854 - INFO - Processed document_part_classification_32_lines.txt: 22 original lines -> 30 processed lines
# 2025-03-22 15:53:20,855 - INFO - Processed document_part_classification_210_lines.txt: 5 original lines -> 7 processed lines
# 2025-03-22 15:53:20,856 - INFO - Processed document_part_classification_483_lines.txt: 37 original lines -> 42 processed lines
# 2025-03-22 15:53:20,857 - INFO - Processed document_part_classification_160_lines.txt: 13 original lines -> 15 processed lines
# 2025-03-22 15:53:20,857 - INFO - Processed document_part_classification_356_lines.txt: 40 original lines -> 58 processed lines
# 2025-03-22 15:53:20,858 - INFO - Processed document_part_classification_69_lines.txt: 6 original lines -> 6 processed lines
# 2025-03-22 15:53:20,859 - INFO - Processed document_part_classification_430_lines.txt: 10 original lines -> 10 processed lines
# 2025-03-22 15:53:20,859 - INFO - Processed document_part_classification_606_lines.txt: 7 original lines -> 7 processed lines
# 2025-03-22 15:53:20,859 - INFO - Processed document_part_classification_576_lines.txt: 5 original lines -> 8 processed lines
# 2025-03-22 15:53:20,860 - INFO - Processed document_part_classification_13_lines.txt: 11 original lines -> 16 processed lines
# 2025-03-22 15:53:20,861 - INFO - Processed document_part_classification_562_lines.txt: 35 original lines -> 46 processed lines
# 2025-03-22 15:53:20,861 - INFO - Processed document_part_classification_612_lines.txt: 21 original lines -> 21 processed lines
# 2025-03-22 15:53:20,862 - INFO - Processed document_part_classification_338_lines.txt: 6 original lines -> 6 processed lines
# 2025-03-22 15:53:20,862 - INFO - Processed document_part_classification_424_lines.txt: 24 original lines -> 49 processed lines
# 2025-03-22 15:53:20,863 - INFO - Processed document_part_classification_342_lines.txt: 31 original lines -> 31 processed lines
# 2025-03-22 15:53:20,863 - INFO - Processed document_part_classification_174_lines.txt: 22 original lines -> 22 processed lines
# 2025-03-22 15:53:20,864 - INFO - Processed document_part_classification_497_lines.txt: 12 original lines -> 26 processed lines
# 2025-03-22 15:53:20,864 - INFO - Processed document_part_classification_204_lines.txt: 3 original lines -> 3 processed lines
# 2025-03-22 15:53:20,865 - INFO - Processed document_part_classification_518_lines.txt: 27 original lines -> 45 processed lines
# 2025-03-22 15:53:20,866 - INFO - Processed document_part_classification_314_lines.txt: 25 original lines -> 31 processed lines
# 2025-03-22 15:53:20,866 - INFO - Processed document_part_classification_408_lines.txt: 2 original lines -> 6 processed lines
# 2025-03-22 15:53:20,867 - INFO - Processed document_part_classification_122_lines.txt: 8 original lines -> 8 processed lines
# 2025-03-22 15:53:20,867 - INFO - Processed document_part_classification_252_lines.txt: 13 original lines -> 13 processed lines
# 2025-03-22 15:53:20,868 - INFO - Processed document_part_classification_587_lines.txt: 14 original lines -> 14 processed lines
# 2025-03-22 15:53:20,868 - INFO - Processed document_part_classification_228_lines.txt: 11 original lines -> 19 processed lines
# 2025-03-22 15:53:20,869 - INFO - Processed document_part_classification_534_lines.txt: 15 original lines -> 43 processed lines
# 2025-03-22 15:53:20,870 - INFO - Processed document_part_classification_644_lines.txt: 16 original lines -> 41 processed lines
# 2025-03-22 15:53:20,870 - INFO - Processed document_part_classification_191_lines.txt: 3 original lines -> 8 processed lines
# 2025-03-22 15:53:20,871 - INFO - Processed document_part_classification_472_lines.txt: 17 original lines -> 35 processed lines
# 2025-03-22 15:53:20,872 - INFO - Processed document_part_classification_158_lines.txt: 14 original lines -> 48 processed lines
# 2025-03-22 15:53:20,872 - INFO - Processed document_part_classification_51_lines.txt: 7 original lines -> 7 processed lines
# 2025-03-22 15:53:20,873 - INFO - Processed document_part_classification_98_lines.txt: 11 original lines -> 11 processed lines
# 2025-03-22 15:53:20,873 - INFO - Processed document_part_classification_45_lines.txt: 1 original lines -> 1 processed lines
# 2025-03-22 15:53:20,874 - INFO - Processed document_part_classification_466_lines.txt: 21 original lines -> 50 processed lines
# 2025-03-22 15:53:20,874 - INFO - Processed document_part_classification_185_lines.txt: 22 original lines -> 22 processed lines
# 2025-03-22 15:53:20,875 - INFO - Processed document_part_classification_650_lines.txt: 33 original lines -> 47 processed lines
# 2025-03-22 15:53:20,876 - INFO - Processed document_part_classification_520_lines.txt: 31 original lines -> 31 processed lines
# 2025-03-22 15:53:20,876 - INFO - Processed document_part_classification_593_lines.txt: 28 original lines -> 32 processed lines
# 2025-03-22 15:53:20,877 - INFO - Processed document_part_classification_246_lines.txt: 11 original lines -> 11 processed lines
# 2025-03-22 15:53:20,877 - INFO - Processed document_part_classification_136_lines.txt: 21 original lines -> 21 processed lines
# 2025-03-22 15:53:20,878 - INFO - Processed document_part_classification_300_lines.txt: 40 original lines -> 40 processed lines
# 2025-03-22 15:53:20,878 - INFO - Processed document_part_classification_64_lines.txt: 20 original lines -> 23 processed lines
# 2025-03-22 15:53:20,879 - INFO - Processed document_part_classification_392_lines.txt: 23 original lines -> 23 processed lines
# 2025-03-22 15:53:20,880 - INFO - Processed document_part_classification_447_lines.txt: 18 original lines -> 49 processed lines
# 2025-03-22 15:53:20,880 - INFO - Processed document_part_classification_501_lines.txt: 5 original lines -> 10 processed lines
# 2025-03-22 15:53:20,881 - INFO - Processed document_part_classification_267_lines.txt: 14 original lines -> 14 processed lines
# 2025-03-22 15:53:20,881 - INFO - Processed document_part_classification_321_lines.txt: 3 original lines -> 19 processed lines
# 2025-03-22 15:53:20,882 - INFO - Processed document_part_classification_117_lines.txt: 5 original lines -> 5 processed lines
# 2025-03-22 15:53:20,882 - INFO - Processed document_part_classification_6_lines.txt: 13 original lines -> 13 processed lines
# 2025-03-22 15:53:20,883 - INFO - Processed document_part_classification_103_lines.txt: 2 original lines -> 2 processed lines
# 2025-03-22 15:53:20,883 - INFO - Processed document_part_classification_429_lines.txt: 15 original lines -> 43 processed lines
# 2025-03-22 15:53:20,884 - INFO - Processed document_part_classification_335_lines.txt: 54 original lines -> 64 processed lines
# 2025-03-22 15:53:20,884 - INFO - Processed document_part_classification_273_lines.txt: 19 original lines -> 28 processed lines
# 2025-03-22 15:53:20,885 - INFO - Processed document_part_classification_515_lines.txt: 9 original lines -> 31 processed lines
# 2025-03-22 15:53:20,886 - INFO - Processed document_part_classification_209_lines.txt: 13 original lines -> 26 processed lines
# 2025-03-22 15:53:20,886 - INFO - Processed document_part_classification_179_lines.txt: 25 original lines -> 25 processed lines
# 2025-03-22 15:53:20,887 - INFO - Processed document_part_classification_453_lines.txt: 21 original lines -> 29 processed lines
# 2025-03-22 15:53:20,887 - INFO - Processed document_part_classification_386_lines.txt: 18 original lines -> 18 processed lines
# 2025-03-22 15:53:20,888 - INFO - Processed document_part_classification_70_lines.txt: 15 original lines -> 30 processed lines
# 2025-03-22 15:53:20,889 - INFO - Processed document_part_classification_37_lines.txt: 12 original lines -> 29 processed lines
# 2025-03-22 15:53:20,889 - INFO - Processed document_part_classification_308_lines.txt: 48 original lines -> 48 processed lines
# 2025-03-22 15:53:20,890 - INFO - Processed document_part_classification_622_lines.txt: 13 original lines -> 20 processed lines
# 2025-03-22 15:53:20,890 - INFO - Processed document_part_classification_414_lines.txt: 78 original lines -> 78 processed lines
# 2025-03-22 15:53:20,891 - INFO - Processed document_part_classification_287_lines.txt: 15 original lines -> 15 processed lines
# 2025-03-22 15:53:20,891 - INFO - Processed document_part_classification_552_lines.txt: 30 original lines -> 30 processed lines
# 2025-03-22 15:53:20,892 - INFO - Processed document_part_classification_84_lines.txt: 28 original lines -> 28 processed lines
# 2025-03-22 15:53:20,892 - INFO - Processed document_part_classification_234_lines.txt: 21 original lines -> 24 processed lines
# 2025-03-22 15:53:20,893 - INFO - Processed document_part_classification_528_lines.txt: 4 original lines -> 34 processed lines
# 2025-03-22 15:53:20,894 - INFO - Processed document_part_classification_372_lines.txt: 9 original lines -> 23 processed lines
# 2025-03-22 15:53:20,894 - INFO - Processed document_part_classification_144_lines.txt: 11 original lines -> 11 processed lines
# 2025-03-22 15:53:20,895 - INFO - Processed document_part_classification_150_lines.txt: 12 original lines -> 20 processed lines
# 2025-03-22 15:53:20,895 - INFO - Processed document_part_classification_199_lines.txt: 12 original lines -> 12 processed lines
# 2025-03-22 15:53:20,896 - INFO - Processed document_part_classification_366_lines.txt: 19 original lines -> 19 processed lines
# 2025-03-22 15:53:20,896 - INFO - Processed document_part_classification_220_lines.txt: 3 original lines -> 3 processed lines
# 2025-03-22 15:53:20,897 - INFO - Processed document_part_classification_90_lines.txt: 6 original lines -> 6 processed lines
# 2025-03-22 15:53:20,897 - INFO - Processed document_part_classification_59_lines.txt: 8 original lines -> 8 processed lines
# 2025-03-22 15:53:20,898 - INFO - Processed document_part_classification_546_lines.txt: 17 original lines -> 25 processed lines
# 2025-03-22 15:53:20,898 - INFO - Processed document_part_classification_293_lines.txt: 5 original lines -> 5 processed lines
# 2025-03-22 15:53:20,899 - INFO - Processed document_part_classification_400_lines.txt: 24 original lines -> 59 processed lines
# 2025-03-22 15:53:20,900 - INFO - Processed document_part_classification_636_lines.txt: 12 original lines -> 30 processed lines
# 2025-03-22 15:53:20,900 - INFO - Processed document_part_classification_23_lines.txt: 16 original lines -> 29 processed lines
# 2025-03-22 15:53:20,901 - INFO - Processed document_part_classification_347_lines.txt: 30 original lines -> 76 processed lines
# 2025-03-22 15:53:20,902 - INFO - Processed document_part_classification_171_lines.txt: 7 original lines -> 18 processed lines
# 2025-03-22 15:53:20,902 - INFO - Processed document_part_classification_492_lines.txt: 56 original lines -> 56 processed lines
# 2025-03-22 15:53:20,903 - INFO - Processed document_part_classification_201_lines.txt: 6 original lines -> 10 processed lines
# 2025-03-22 15:53:20,903 - INFO - Processed document_part_classification_78_lines.txt: 41 original lines -> 41 processed lines
# 2025-03-22 15:53:20,904 - INFO - Processed document_part_classification_567_lines.txt: 11 original lines -> 39 processed lines
# 2025-03-22 15:53:20,904 - INFO - Processed document_part_classification_617_lines.txt: 36 original lines -> 36 processed lines
# 2025-03-22 15:53:20,905 - INFO - Processed document_part_classification_421_lines.txt: 21 original lines -> 67 processed lines
# 2025-03-22 15:53:20,906 - INFO - Processed document_part_classification_16_lines.txt: 17 original lines -> 17 processed lines
# 2025-03-22 15:53:20,906 - INFO - Processed document_part_classification_435_lines.txt: 37 original lines -> 37 processed lines
# 2025-03-22 15:53:20,907 - INFO - Processed document_part_classification_603_lines.txt: 19 original lines -> 19 processed lines
# 2025-03-22 15:53:20,908 - INFO - Processed document_part_classification_329_lines.txt: 25 original lines -> 25 processed lines
# 2025-03-22 15:53:20,908 - INFO - Processed document_part_classification_573_lines.txt: 9 original lines -> 24 processed lines
# 2025-03-22 15:53:20,909 - INFO - Processed document_part_classification_509_lines.txt: 15 original lines -> 47 processed lines
# 2025-03-22 15:53:20,910 - INFO - Processed document_part_classification_215_lines.txt: 20 original lines -> 20 processed lines
# 2025-03-22 15:53:20,910 - INFO - Processed document_part_classification_486_lines.txt: 24 original lines -> 38 processed lines
# 2025-03-22 15:53:20,911 - INFO - Processed document_part_classification_165_lines.txt: 5 original lines -> 8 processed lines
# 2025-03-22 15:53:20,912 - INFO - Processed document_part_classification_353_lines.txt: 7 original lines -> 15 processed lines
# 2025-03-22 15:53:20,912 - INFO - Processed document_part_classification_596_lines.txt: 29 original lines -> 29 processed lines
# 2025-03-22 15:53:20,913 - INFO - Processed document_part_classification_243_lines.txt: 32 original lines -> 40 processed lines
# 2025-03-22 15:53:20,913 - INFO - Processed document_part_classification_419_lines.txt: 28 original lines -> 28 processed lines
# 2025-03-22 15:53:20,914 - INFO - Processed document_part_classification_133_lines.txt: 40 original lines -> 65 processed lines
# 2025-03-22 15:53:20,915 - INFO - Processed document_part_classification_305_lines.txt: 13 original lines -> 41 processed lines
# 2025-03-22 15:53:20,915 - INFO - Processed document_part_classification_463_lines.txt: 27 original lines -> 53 processed lines
# 2025-03-22 15:53:20,916 - INFO - Processed document_part_classification_180_lines.txt: 15 original lines -> 18 processed lines
# 2025-03-22 15:53:20,916 - INFO - Processed document_part_classification_149_lines.txt: 10 original lines -> 22 processed lines
# 2025-03-22 15:53:20,917 - INFO - Processed document_part_classification_655_lines.txt: 39 original lines -> 59 processed lines
# 2025-03-22 15:53:20,918 - INFO - Processed document_part_classification_525_lines.txt: 44 original lines -> 61 processed lines
# 2025-03-22 15:53:20,918 - INFO - Processed document_part_classification_239_lines.txt: 9 original lines -> 19 processed lines
# ...
# 2025-03-22 15:53:21,014 - INFO - Processed document_part_classification_530_lines.txt: 6 original lines -> 35 processed lines
# 2025-03-22 15:53:21,015 - INFO - Processed document_part_classification_256_lines.txt: 4 original lines -> 4 processed lines
# 2025-03-22 15:53:21,016 - INFO - Processed document_part_classification_583_lines.txt: 14 original lines -> 39 processed lines
# 2025-03-22 15:53:21,016 - INFO - Processed document_part_classification_310_lines.txt: 12 original lines -> 23 processed lines
# 2025-03-22 15:53:21,017 - INFO - Processed document_part_classification_126_lines.txt: 2 original lines -> 2 processed lines
# 2025-03-22 15:53:21,017 - INFO - Processed document_part_classification_418_lines.txt: 35 original lines -> 35 processed lines
# 2025-03-22 15:53:21,018 - INFO - Processed document_part_classification_132_lines.txt: 6 original lines -> 6 processed lines
# 2025-03-22 15:53:21,018 - INFO - Processed document_part_classification_304_lines.txt: 32 original lines -> 32 processed lines
# 2025-03-22 15:53:21,019 - INFO - Processed document_part_classification_597_lines.txt: 8 original lines -> 36 processed lines
# 2025-03-22 15:53:21,019 - INFO - Processed document_part_classification_242_lines.txt: 21 original lines -> 21 processed lines
# 2025-03-22 15:53:21,020 - INFO - Processed document_part_classification_524_lines.txt: 34 original lines -> 34 processed lines
# 2025-03-22 15:53:21,020 - INFO - Processed document_part_classification_238_lines.txt: 10 original lines -> 10 processed lines
# 2025-03-22 15:53:21,021 - INFO - Processed document_part_classification_462_lines.txt: 11 original lines -> 39 processed lines
# 2025-03-22 15:53:21,022 - INFO - Processed document_part_classification_181_lines.txt: 13 original lines -> 13 processed lines
# 2025-03-22 15:53:21,022 - INFO - Processed document_part_classification_148_lines.txt: 5 original lines -> 9 processed lines
# 2025-03-22 15:53:21,023 - INFO - Processed document_part_classification_654_lines.txt: 23 original lines -> 23 processed lines
# 2025-03-22 15:53:21,023 - INFO - Processed document_part_classification_41_lines.txt: 12 original lines -> 12 processed lines
# 2025-03-22 15:53:21,024 - INFO - Processed document_part_classification_88_lines.txt: 19 original lines -> 33 processed lines
# 2025-03-22 15:53:21,024 - INFO - Processed document_part_classification_325_lines.txt: 21 original lines -> 21 processed lines
# 2025-03-22 15:53:21,025 - INFO - Processed document_part_classification_113_lines.txt: 47 original lines -> 53 processed lines
# 2025-03-22 15:53:21,025 - INFO - Processed document_part_classification_2_lines.txt: 24 original lines -> 24 processed lines
# 2025-03-22 15:53:21,026 - INFO - Processed document_part_classification_439_lines.txt: 42 original lines -> 94 processed lines
# 2025-03-22 15:53:21,026 - INFO - Processed document_part_classification_263_lines.txt: 43 original lines -> 43 processed lines
# 2025-03-22 15:53:21,027 - INFO - Processed document_part_classification_219_lines.txt: 9 original lines -> 16 processed lines
# 2025-03-22 15:53:21,028 - INFO - Processed document_part_classification_505_lines.txt: 39 original lines -> 64 processed lines
# 2025-03-22 15:53:21,028 - INFO - Processed document_part_classification_396_lines.txt: 24 original lines -> 92 processed lines
# 2025-03-22 15:53:21,029 - INFO - Processed document_part_classification_169_lines.txt: 26 original lines -> 31 processed lines
# 2025-03-22 15:53:21,029 - INFO - Processed document_part_classification_443_lines.txt: 14 original lines -> 28 processed lines
# 2025-03-22 15:53:21,030 - INFO - Processed document_part_classification_60_lines.txt: 6 original lines -> 6 processed lines
# 2025-03-22 15:53:21,030 - INFO - Processed document_part_classification_74_lines.txt: 21 original lines -> 21 processed lines
# 2025-03-22 15:53:21,031 - INFO - Processed document_part_classification_457_lines.txt: 41 original lines -> 41 processed lines
# 2025-03-22 15:53:21,032 - INFO - Processed document_part_classification_382_lines.txt: 6 original lines -> 6 processed lines
# 2025-03-22 15:53:21,032 - INFO - Processed document_part_classification_511_lines.txt: 10 original lines -> 37 processed lines
# 2025-03-22 15:53:21,033 - INFO - Processed document_part_classification_277_lines.txt: 22 original lines -> 34 processed lines
# 2025-03-22 15:53:21,033 - INFO - Processed document_part_classification_107_lines.txt: 24 original lines -> 24 processed lines
# 2025-03-22 15:53:21,034 - INFO - Processed document_part_classification_331_lines.txt: 8 original lines -> 48 processed lines
# 2025-03-22 15:53:21,035 - INFO - Processed document_part_classification_212_lines.txt: 6 original lines -> 12 processed lines
# 2025-03-22 15:53:21,035 - INFO - Processed document_part_classification_448_lines.txt: 50 original lines -> 57 processed lines
# 2025-03-22 15:53:21,036 - INFO - Processed document_part_classification_481_lines.txt: 8 original lines -> 18 processed lines
# 2025-03-22 15:53:21,036 - INFO - Processed document_part_classification_162_lines.txt: 6 original lines -> 6 processed lines
# 2025-03-22 15:53:21,037 - INFO - Processed document_part_classification_354_lines.txt: 42 original lines -> 42 processed lines
# 2025-03-22 15:53:21,037 - INFO - Processed document_part_classification_11_lines.txt: 6 original lines -> 6 processed lines
# 2025-03-22 15:53:21,038 - INFO - Processed document_part_classification_432_lines.txt: 10 original lines -> 39 processed lines
# 2025-03-22 15:53:21,038 - INFO - Processed document_part_classification_118_lines.txt: 7 original lines -> 7 processed lines
# 2025-03-22 15:53:21,039 - INFO - Processed document_part_classification_9_lines.txt: 30 original lines -> 30 processed lines
# 2025-03-22 15:53:21,039 - INFO - Processed document_part_classification_604_lines.txt: 16 original lines -> 16 processed lines
# 2025-03-22 15:53:21,040 - INFO - Processed document_part_classification_574_lines.txt: 27 original lines -> 87 processed lines
# 2025-03-22 15:53:21,040 - INFO - Processed document_part_classification_268_lines.txt: 14 original lines -> 17 processed lines
# 2025-03-22 15:53:21,041 - INFO - Processed document_part_classification_560_lines.txt: 14 original lines -> 68 processed lines
# 2025-03-22 15:53:21,042 - INFO - Processed document_part_classification_610_lines.txt: 16 original lines -> 16 processed lines
# 2025-03-22 15:53:21,042 - INFO - Processed document_part_classification_426_lines.txt: 8 original lines -> 8 processed lines
# 2025-03-22 15:53:21,049 - INFO - Processed document_part_classification_389_lines.txt: 31 original lines -> 31 processed lines
# 2025-03-22 15:53:21,049 - INFO - Processed document_part_classification_340_lines.txt: 53 original lines -> 58 processed lines
# 2025-03-22 15:53:21,050 - INFO - Processed document_part_classification_176_lines.txt: 4 original lines -> 4 processed lines
# 2025-03-22 15:53:21,051 - INFO - Processed document_part_classification_495_lines.txt: 28 original lines -> 58 processed lines
# 2025-03-22 15:53:21,052 - INFO - Processed document_part_classification_206_lines.txt: 18 original lines -> 18 processed lines
# 2025-03-22 15:53:21,053 - INFO - Processed document_part_classification_588_lines.txt: 4 original lines -> 4 processed lines
# 2025-03-22 15:53:21,054 - INFO - Processed document_part_classification_541_lines.txt: 33 original lines -> 47 processed lines
# 2025-03-22 15:53:21,054 - INFO - Processed document_part_classification_294_lines.txt: 22 original lines -> 22 processed lines
# 2025-03-22 15:53:21,055 - INFO - Processed document_part_classification_407_lines.txt: 13 original lines -> 27 processed lines
# 2025-03-22 15:53:21,055 - INFO - Processed document_part_classification_631_lines.txt: 17 original lines -> 21 processed lines
# 2025-03-22 15:53:21,056 - INFO - Processed document_part_classification_24_lines.txt: 17 original lines -> 20 processed lines
# 2025-03-22 15:53:21,057 - INFO - Processed document_part_classification_157_lines.txt: 44 original lines -> 74 processed lines
# 2025-03-22 15:53:21,057 - INFO - Processed document_part_classification_361_lines.txt: 25 original lines -> 39 processed lines
# 2025-03-22 15:53:21,058 - INFO - Processed document_part_classification_227_lines.txt: 12 original lines -> 19 processed lines
# 2025-03-22 15:53:21,058 - INFO - Processed document_part_classification_97_lines.txt: 18 original lines -> 21 processed lines
# 2025-03-22 15:53:21,059 - INFO - Processed document_part_classification_83_lines.txt: 6 original lines -> 12 processed lines
# 2025-03-22 15:53:21,059 - INFO - Processed document_part_classification_233_lines.txt: 26 original lines -> 26 processed lines
# 2025-03-22 15:53:21,060 - INFO - Processed document_part_classification_375_lines.txt: 32 original lines -> 32 processed lines
# 2025-03-22 15:53:21,060 - INFO - Processed document_part_classification_143_lines.txt: 11 original lines -> 11 processed lines
# 2025-03-22 15:53:21,061 - INFO - Processed document_part_classification_469_lines.txt: 8 original lines -> 13 processed lines
# 2025-03-22 15:53:21,062 - INFO - Processed document_part_classification_30_lines.txt: 34 original lines -> 34 processed lines
# 2025-03-22 15:53:21,062 - INFO - Processed document_part_classification_625_lines.txt: 45 original lines -> 57 processed lines
# 2025-03-22 15:53:21,063 - INFO - Processed document_part_classification_139_lines.txt: 13 original lines -> 16 processed lines
# 2025-03-22 15:53:21,064 - INFO - Processed document_part_classification_413_lines.txt: 50 original lines -> 54 processed lines
# 2025-03-22 15:53:21,064 - INFO - Processed document_part_classification_249_lines.txt: 28 original lines -> 28 processed lines
# 2025-03-22 15:53:21,065 - INFO - Processed document_part_classification_280_lines.txt: 19 original lines -> 35 processed lines
# 2025-03-22 15:53:21,065 - INFO - Processed document_part_classification_555_lines.txt: 50 original lines -> 50 processed lines
# 2025-03-22 15:53:21,066 - INFO - Processed document_part_classification_359_lines.txt: 3 original lines -> 3 processed lines
# 2025-03-22 15:53:21,066 - INFO - Processed document_part_classification_390_lines.txt: 8 original lines -> 58 processed lines
# 2025-03-22 15:53:21,067 - INFO - Processed document_part_classification_445_lines.txt: 26 original lines -> 90 processed lines
# 2025-03-22 15:53:21,068 - INFO - Processed document_part_classification_503_lines.txt: 19 original lines -> 27 processed lines
# 2025-03-22 15:53:21,068 - INFO - Processed document_part_classification_66_lines.txt: 15 original lines -> 15 processed lines
# 2025-03-22 15:53:21,069 - INFO - Processed document_part_classification_265_lines.txt: 11 original lines -> 16 processed lines
# 2025-03-22 15:53:21,069 - INFO - Processed document_part_classification_579_lines.txt: 6 original lines -> 6 processed lines
# 2025-03-22 15:53:21,070 - INFO - Processed document_part_classification_323_lines.txt: 12 original lines -> 57 processed lines
# 2025-03-22 15:53:21,071 - INFO - Processed document_part_classification_609_lines.txt: 17 original lines -> 17 processed lines
# 2025-03-22 15:53:21,071 - INFO - Processed document_part_classification_115_lines.txt: 29 original lines -> 57 processed lines
# 2025-03-22 15:53:21,072 - INFO - Processed document_part_classification_4_lines.txt: 3 original lines -> 3 processed lines
# 2025-03-22 15:53:21,072 - INFO - Processed document_part_classification_101_lines.txt: 17 original lines -> 52 processed lines
# 2025-03-22 15:53:21,073 - INFO - Processed document_part_classification_337_lines.txt: 11 original lines -> 36 processed lines
# 2025-03-22 15:53:21,074 - INFO - Processed document_part_classification_271_lines.txt: 14 original lines -> 18 processed lines
# 2025-03-22 15:53:21,074 - INFO - Processed document_part_classification_72_lines.txt: 15 original lines -> 34 processed lines
# 2025-03-22 15:53:21,075 - INFO - Processed document_part_classification_517_lines.txt: 22 original lines -> 35 processed lines
# 2025-03-22 15:53:21,075 - INFO - Processed document_part_classification_498_lines.txt: 21 original lines -> 31 processed lines
# 2025-03-22 15:53:21,076 - INFO - Processed document_part_classification_451_lines.txt: 26 original lines -> 26 processed lines
# 2025-03-22 15:53:21,076 - INFO - Processed document_part_classification_384_lines.txt: 21 original lines -> 21 processed lines
# 2025-03-22 15:53:21,077 - INFO - Processed document_part_classification_29_lines.txt: 3 original lines -> 6 processed lines
# 2025-03-22 15:53:21,078 - INFO - Processed document_part_classification_316_lines.txt: 14 original lines -> 14 processed lines
# 2025-03-22 15:53:21,078 - INFO - Processed document_part_classification_120_lines.txt: 44 original lines -> 44 processed lines
# 2025-03-22 15:53:21,079 - INFO - Processed document_part_classification_299_lines.txt: 12 original lines -> 12 processed lines
# 2025-03-22 15:53:21,079 - INFO - Processed document_part_classification_250_lines.txt: 16 original lines -> 16 processed lines
# 2025-03-22 15:53:21,080 - INFO - Processed document_part_classification_585_lines.txt: 15 original lines -> 15 processed lines
# 2025-03-22 15:53:21,080 - INFO - Processed document_part_classification_53_lines.txt: 12 original lines -> 12 processed lines
# 2025-03-22 15:53:21,081 - INFO - Processed document_part_classification_536_lines.txt: 29 original lines -> 41 processed lines
# 2025-03-22 15:53:21,082 - INFO - Processed document_part_classification_646_lines.txt: 19 original lines -> 32 processed lines
# 2025-03-22 15:53:21,082 - INFO - Processed document_part_classification_193_lines.txt: 29 original lines -> 29 processed lines
# 2025-03-22 15:53:21,083 - INFO - Processed document_part_classification_470_lines.txt: 18 original lines -> 30 processed lines
# 2025-03-22 15:53:21,083 - INFO - Processed document_part_classification_464_lines.txt: 31 original lines -> 62 processed lines
# 2025-03-22 15:53:21,084 - INFO - Processed document_part_classification_187_lines.txt: 25 original lines -> 25 processed lines
# 2025-03-22 15:53:21,084 - INFO - Processed document_part_classification_652_lines.txt: 27 original lines -> 27 processed lines
# 2025-03-22 15:53:21,085 - INFO - Processed document_part_classification_378_lines.txt: 40 original lines -> 40 processed lines
# 2025-03-22 15:53:21,086 - INFO - Processed document_part_classification_522_lines.txt: 34 original lines -> 34 processed lines
# 2025-03-22 15:53:21,086 - INFO - Processed document_part_classification_47_lines.txt: 9 original lines -> 23 processed lines
# 2025-03-22 15:53:21,087 - INFO - Processed document_part_classification_558_lines.txt: 11 original lines -> 29 processed lines
# 2025-03-22 15:53:21,087 - INFO - Processed document_part_classification_591_lines.txt: 11 original lines -> 28 processed lines
# 2025-03-22 15:53:21,088 - INFO - Processed document_part_classification_244_lines.txt: 21 original lines -> 31 processed lines
# 2025-03-22 15:53:21,088 - INFO - Processed document_part_classification_134_lines.txt: 6 original lines -> 17 processed lines
# 2025-03-22 15:53:21,089 - INFO - Processed document_part_classification_628_lines.txt: 3 original lines -> 3 processed lines
# 2025-03-22 15:53:21,090 - INFO - Processed document_part_classification_302_lines.txt: 19 original lines -> 55 processed lines
# 2025-03-22 15:53:21,090 - INFO -
# Text line splitting complete:
# 2025-03-22 15:53:21,090 - INFO - Files processed: 656
# 2025-03-22 15:53:21,090 - INFO - TEXT lines: 891 original -> 7673 processed
# 2025-03-22 15:53:21,090 - INFO - FORM lines: 7437 original -> 7437 processed
# 2025-03-22 15:53:21,090 - INFO - TABLE lines: 4524 original -> 4524 processed
# 2025-03-22 15:53:21,090 - INFO - TEXT average length: 639.1 chars -> 73.4 chars
# 2025-03-22 15:53:21,091 - INFO - FORM average length: 65.6 chars -> 65.6 chars
# 2025-03-22 15:53:21,091 - INFO - TABLE average length: 83.6 chars -> 83.6 chars
# Original dataset:
# TEXT: 891 lines (6.9%)
# FORM: 7437 lines (57.9%)
# TABLE: 4524 lines (35.2%)
#
# Processed dataset:
# TEXT: 7673 lines (39.1%)
# FORM: 7437 lines (37.9%)
# TABLE: 4524 lines (23.0%)
